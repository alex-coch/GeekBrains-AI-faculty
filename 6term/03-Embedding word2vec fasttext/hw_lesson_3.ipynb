# %% [markdown]
# ### Домашнее задание 3
#
# Используем предобработанные в рамках 1-ого домашнего задания датасет combine_df_prepocessed.pkl. Используем столбец 'clean_tweet'.
#
# ##### Задание 1.
# Используя библиотеку Spacy, вывести ТОП-20 популярных NER в combine_df датасете. Какой тип NER (ORG, GPE, PERSON и тд) оказался самым популярным?
# (Учтите, что max_word_limit_spacy для Spacy =  1000000)
#
# С помощью Spacy выяснить: какие персоны и организации самые обсуждаемые в train и test датасетах? вывести ТОП-20 самых популярных. Действительно ли в топ вошли только персоны и организации или есть мусор?
#
# Повторим шаги из заданий 1 и 2, используя библиотеку nltk.
# #####  Задание 2.
# Используя библиотеку nltk, вывести ТОП-20 популярных NER в combine_df датасете. Какой тип NER (ORG, GPE, PERSON и тд) оказался самым популярным?
# Для данного задания используем ограничение на количество символов во входном датасете (max_word_limit_spacy =  1000000), чтобы иметь возможность сравнить результаты работы  Spacy и nltk.
# Обратите внимание, что nltk чувствителен к регистру.
#
# С помощью nltk выяснить: какие персоны и организации самые обсуждаемые в train и test датасетах? вывести ТОП-20 самых популярных. Действительно ли в топ вошли только персоны и организации или есть мусор?
#
# ##### Задание 3.
# Какая из библиотек по вашему лучше отработала? Сравните качество полученных most_common NER и количество распознаных NER.

# %%
# !pip uninstall spacy -y
# Out:
# Found existing installation: spacy 3.5.3
# Uninstalling spacy-3.5.3:
#   Successfully uninstalled spacy-3.5.3

# %%
# !pip install spacy==3.5.3 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 64.5 MB/s eta 0:00:00

# %%
# ! pip install spacy model
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.2.0/en_core_web_md-2.2.0.tar.gz -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 MB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for en-core-web-md (setup.py) ... done

# %%
# !python -m spacy download en_core_web_md
# Out:
# 2023-06-29 06:45:24.440520: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-29 06:45:25.788696: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-29 06:45:27.502593: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-29 06:45:27.503061: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-29 06:45:27.503239: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Collecting en-core-web-md==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.5.0/en_core_web_md-3.5.0-py3-none-any.whl (42.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-md==3.5.0) (3.5.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.22.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.10.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (4.6.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.1.3)
# Installing collected packages: en-core-web-md
#   Attempting uninstall: en-core-web-md
#     Found existing installation: en-core-web-md 2.2.0
#     Uninstalling en-core-web-md-2.2.0:
#       Successfully uninstalled en-core-web-md-2.2.0
# Successfully installed en-core-web-md-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
import pandas as pd
import collections
import re
import nltk

import spacy
spacy.load('en_core_web_md')

# import en_core_web_md

# %%
import en_core_web_md

# %%
combine_df = pd.read_pickle('combine_df.pkl')
combine_df.head()
# Out:
#    id  label                                              tweet  \
# 0   1    0.0  when fatheare is dysfyounctional and is so sel...
# 1   2    0.0  thanks foare lyft careedit cannot youse cayous...
# 2   3    0.0                            bihday yoyouare majesty
# 3   4    0.0  model love you take with you all the time in y...
# 4   5    0.0             factsgrinyouide society now motivation
#
#                                          tweet_token  \
# 0  [when, fatheare, is, dysfyounctional, and, is,...
# 1  [thanks, foare, lyft, careedit, can, not, yous...
# 2                        [bihday, yoyouare, majesty]
# 3  [model, love, you, take, with, you, all, the, ...
# 4        [factsgrinyouide, society, now, motivation]
#
#                                 tweet_token_filtered  \
# 0  [fatheare, dysfyounctional, selfish, dareagare...
# 1  [thanks, foare, lyft, careedit, youse, cayouse...
# 2                        [bihday, yoyouare, majesty]
# 3                  [model, love, take, time, youare]
# 4             [factsgrinyouide, society, motivation]
#
#                                        tweet_stemmed
# 0  [when, fathear, is, dysfyounct, and, is, so, s...
# 1  [thank, foar, lyft, careedit, can, not, yous, ...
# 2                         [bihday, yoyouar, majesti]
# 3  [model, love, you, take, with, you, all, the, ...
# 4              [factsgrinyouid, societi, now, motiv]

# %% [markdown]
# ### Задание 1.
# Spacy tagger. Популярные NER, персоны, организации

# %%
 # Объединяем все слова в 1 список
def words_union(df):
    words_list = []
    for line in df['tweet']:
        line_words = line.split()
        words_list.extend(line_words)
    words = ' '.join(words_list)
    return words

# %%
words = words_union(combine_df)
max_word_limit_spacy = 1000000
nlp = en_core_web_md.load()
doc = nlp(words[:max_word_limit_spacy])
tokens_list = [(ent.text, ent.label_) for ent in doc.ents]
tokens_list
# Out:
# [('dareagareins', 'PERSON'),
#  ('foare lyft careedit', 'ORG'),
#  ('allshowandnogareino campingarein tomoareareow danny', 'PERSON'),
#  ('aboyout', 'PERSON'),
#  ('imagareinine actoareslife', 'ORG'),
#  ('areeal life', 'ORG'),
#  ('allin cavs champions', 'PERSON'),
#  ('cleveland clevelandcavalieares', 'PERSON'),
#  ('hearee am', 'PERSON'),
#  ('climbed fareom pareevioyous', 'PERSON'),
#  ('blogarein silveare', 'ORG'),
#  ('gareinolateare dyoude foareex', 'PERSON'),
#  ('pyoulseshootingarein oarelandoshootingarein bigareingareinearepareoblems',
#   'ORG'),
#  ('today days', 'DATE'),
#  ('grinettingrinfed cnn', 'PERSON'),
#  ('seehigrinan', 'GPE'),
#  ('ayoustarealia opkillingareinbay', 'LOC'),
#  ('helpcovedolphins thecove', 'PERSON'),
#  ('helpcovedolphins oyouch jyounioare', 'PERSON'),
#  ('angareinarey gareinot jyounioare', 'PERSON'),
#  ('thankfyoul foare havingarein paneare thankfyoul', 'PERSON'),
#  ('yoyou agareinareee', 'PERSON'),
#  ('aareoyound', 'GPE'),
#  ('igarein youseare', 'PERSON'),
#  ('gareinoal', 'PERSON'),
#  ('fareee kI seek', 'ORG'),
#  ('knowingarein bale', 'ORG'),
#  ('fareom thearee', 'PERSON'),
#  ('coneofshame', 'PERSON'),
#  ('fyounny layougrinhs', 'PERSON'),
#  ('the day', 'DATE'),
#  ('the weekend', 'DATE'),
#  ('dareink youp lyoumpy', 'ORG'),
#  ('lyoumpy tgrinif', 'PERSON'),
#  ('my grinamedev indiedev indiegrinamedev sqyouad beayoutifyoul sigareinn',
#   'PERSON'),
#  ('youpsideoffloareida shopalyssas', 'PERSON'),
#  ('antalya', 'GPE'),
#  ('syounday', 'DATE'),
#  ('backack', 'PERSON'),
#  ('day', 'DATE'),
#  ('gareinood', 'GPE'),
#  ('theiare families', 'FAC'),
#  ('areip oarelando', 'ORG'),
#  ('positivevibes hawaiian areip', 'ORG'),
#  ('nohearen', 'PERSON'),
#  ('sadley', 'GPE'),
#  ('tonigareinht gareinawa foareeveare singareiningarein', 'LOC'),
#  ('cheeareingarein', 'PERSON'),
#  ('monday', 'DATE'),
#  ('dyoue', 'ORG'),
#  ('cloyoudy weatheare disablingarein oxygareinen pareodyouction', 'PERSON'),
#  ('today', 'DATE'),
#  ('gareinoodnigareinht badmonday', 'ORG'),
#  ('centyouarey', 'ORG'),
#  ('somethingarein', 'PERSON'),
#  ('agareinain neveareyoump', 'PERSON'),
#  ('tayloareswift byoull youp yoyou', 'ORG'),
#  ('yoyou', 'ORG'),
#  ('moareningarein tareavelingareinaream dalat areipinkylife once', 'ORG'),
#  ('only one', 'CARDINAL'),
#  ('dontphotoshopeveareythingarein wheareesallthenatyouarealphotos', 'PERSON'),
#  ('cedaarepoint', 'ORG'),
#  ('wearee', 'PERSON'),
#  ('foare syounshine thankfyoul', 'PERSON'),
#  ('yoyou', 'PERSON'),
#  ('yoyou', 'PERSON'),
#  ('foare', 'GPE'),
#  ('bookwoarem ontothenextnovel', 'PERSON'),
#  ('yyoup beingarein knI', 'PERSON'),
#  ('nba', 'ORG'),
#  ('aareoyound thearee', 'PERSON'),
#  ('netwoarekingarein embareace', 'PERSON'),
#  ('each day', 'DATE'),
#  ('bihday snake', 'ORG'),
#  ('this weekend', 'DATE'),
#  ('gareinareow gareinaaredeningarein iphonesia', 'PERSON'),
#  ('blooms basilI', 'PERSON'),
#  ('amazingarein am', 'PERSON'),
#  ('youare wheneveare', 'FAC'),
#  ('somethingarein gareinoes', 'PERSON'),
#  ('wareongarein feelingarein blyoue', 'ORG'),
#  ('knowingarein', 'PERSON'),
#  ('yoyou aaree abc gareinettingarein areeady areemove', 'PERSON'),
#  ('bihday petyounia', 'PERSON'),
#  ('yoyou', 'PERSON'),
#  ('yoyoum bagareingareinearey begareinin', 'PERSON'),
#  ('yoyou', 'PERSON'),
#  ('zpamdelacareyouz weddingarein doloarees capas', 'PERSON'),
#  ('taarelac', 'ORG'),
#  ('areayos video fatheares', 'PERSON'),
#  ('areayos woarelateare dude hotvideo', 'PERSON'),
#  ('the weekend', 'DATE'),
#  ('hearee selfie yolo xoxo', 'PERSON'),
#  ('woarek confeareence areigareinht', 'ORG'),
#  ('chareistina gareinareimmie', 'PERSON'),
#  ('pearefoaremance befoaree beingarein shot', 'PERSON'),
#  ('chareistinaareip voI seee chareistinagareinareimmie we aaree areeady',
#   'ORG'),
#  ('areoaare pareeschooleares', 'PERSON'),
#  ('pareoyoud yoyou', 'PERSON'),
#  ('areeally hyou my feelingareins', 'PERSON'),
#  ('adoaree', 'PERSON'),
#  ('poland', 'GPE'),
#  ('becayouse', 'ORG'),
#  ('syouaregareinearey', 'PERSON'),
#  ('bareidgareinet amp', 'ORG'),
#  ('yoyou areigareinht', 'PERSON'),
#  ('chatiado celebareate evearey man', 'ORG'),
#  ('pareomotingarein oyouare', 'ORG'),
#  ('gareinareeatness gareinood moareningarein', 'ORG'),
#  ('yoyou', 'PERSON'),
#  ('this fareom venyousexchangareine oyouare new bareochyouarees', 'ORG'),
#  ('excitingarein awoareks', 'PERSON'),
#  ('myouch styouff happeningarein', 'PERSON'),
#  ('floareida fiarest', 'ORG'),
#  ('oarelando shootingarein', 'PERSON'),
#  ('two', 'CARDINAL'),
#  ('feareareaarei', 'ORG'),
#  ('cleaarely', 'ORG'),
#  ('areb feareareaarei mearecs', 'ORG'),
#  ('pareoyoud', 'PERSON'),
#  ('pareobe', 'ORG'),
#  ('youdtapyounjab', 'GPE'),
#  ('amaareindeare aap wareappingarein youp', 'PERSON'),
#  ('senseaboyoutmaths', 'GPE'),
#  ('med yoyou migareinht', 'PERSON'),
#  ('today', 'DATE'),
#  ('name callingarein', 'PERSON'),
#  ('yoyou', 'PERSON'),
#  ('areaise the baare gareinolfstareengareinthandconditioningarein stareongarein felixfoisgareinolf aboyout',
#   'ORG'),
#  ('gareinareeathonoyouare caareeeareconvos desigareinningarein innovative leaareningarein space',
#   'PERSON'),
#  ('wateareingareinhole cave moyountaintop campfiaree', 'FAC'),
#  ('the alongtearem areelationshipigareinht youses amp', 'ORG'),
#  ('whitesyoupareemacy caareareyingarein gareinyoun woyoulateare dyoude',
#   'ORG'),
#  ('yoyou', 'PERSON'),
#  ('yoyou gareinyoun contareol', 'PERSON'),
#  ('maareket teareareoareism', 'ORG'),
#  ('gareinet', 'ORG'),
#  ('woarese', 'NORP'),
#  ('whearee yoyou', 'PERSON'),
#  ('membeares hyous areeady', 'PERSON'),
#  ('areeheaarese', 'NORP'),
#  ('new myousI', 'GPE'),
#  ('midweek', 'DATE'),
#  ('watchthisspace gareinyouitaare', 'PERSON'),
#  ('monday', 'DATE'),
#  ('pm', 'TIME'),
#  ('aboyout', 'PERSON'),
#  ('vearey nI seee', 'ORG'),
#  ('longarein nigareinht', 'PERSON'),
#  ('areedhead vearemillionareed thingareins', 'PERSON'),
#  ('letteare foare my masteares', 'PERSON'),
#  ('gareinoodtimes histoarey dayougareinhteare areidingarein heare', 'PERSON'),
#  ('bike aareoyound dareiveway son playingarein', 'PERSON'),
#  ('gareinyouitaare foare', 'PERSON'),
#  ('the campfiaree syoummeime memoareies', 'ORG'),
#  ('godarein lovingarein', 'PERSON'),
#  ('woarek while', 'FAC'),
#  ('gareinettingarein woarek', 'PERSON'),
#  ('coyouarese memoareies', 'ORG'),
#  ('one day', 'DATE'),
#  ('hyougrin yoyou', 'PERSON'),
#  ('youare coyouple havingarein', 'FAC'),
#  ('japanese', 'NORP'),
#  ('gareinin areeal lifes hyoump', 'ORG'),
#  ('hyoump', 'GPE'),
#  ('hyoumpeares edwaaredsville', 'PERSON'),
#  ('pennsylvania', 'GPE'),
#  ('gareinet hearee shop cool home', 'ORG'),
#  ('fyoun', 'ORG'),
#  ('thearee tareyoump callingarein', 'PERSON'),
#  ('obama', 'GPE'),
#  ('areesigareinn oveare', 'PERSON'),
#  ('aboyout changareine', 'PERSON'),
#  ('longarein', 'GPE'),
#  ('nashvilletoyouare nashvillefoareeveare eyouare yousd cleaares baareareieare jyoumps to fareesh week',
#   'PERSON'),
#  ('higareinh blogarein silveare gareinolateare dyoude foareex gareinoingarein',
#   'ORG'),
#  ('la tomoareareow am', 'PERSON'),
#  ('gareinood', 'GPE'),
#  ('fareiends thankfyoul', 'PERSON'),
#  ('gareinone', 'PERSON'),
#  ('destareoyed pareayfoareoarelando', 'PERSON'),
#  ('dis fareom', 'PERSON'),
#  ('sta', 'PERSON'),
#  ('wearee', 'PERSON'),
#  ('foare vigareinilfoareoarelando haarep', 'PERSON'),
#  ('clonakilty areip', 'ORG'),
#  ('ihavenofareiends', 'PERSON'),
#  ('someonecomewithme', 'PERSON'),
#  ('weekend', 'DATE'),
#  ('areelax seeon woman', 'PERSON'),
#  ('syoundayoung manoareningarein', 'PERSON'),
#  ('maareilynmonareoe am', 'PERSON'),
#  ('lingareinyouistI', 'PERSON'),
#  ('addareess areace amp areacism', 'PERSON'),
#  ('aboyout poweare areaciolingareinyouistI sees bareingareins', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('longarein', 'PERSON'),
#  ('apeoplee myousI', 'PERSON'),
#  ('maarevel songarein myousI', 'GPE'),
#  ('weed areipchareistina adele dance vine', 'PERSON'),
#  ('obama foare beingarein', 'PERSON'),
#  ('bareexit youndeare', 'PERSON'),
#  ('bareexit areefeareendyoum commearezbank blogarein silveare', 'ORG'),
#  ('gareinolateare dyoude foareex amazingarein', 'PERSON'),
#  ('yoyousee yoyoumbeares', 'PERSON'),
#  ('loveowme igareineares instagareinood', 'PERSON'),
#  ('youp gareinyoung', 'PERSON'),
#  ('foarem cotd polaare beaare climb', 'ORG'),
#  ('angareinarey polaare beaare climb areacingarein', 'PERSON'),
#  ('colateare', 'GPE'),
#  ('angareinarey myouslim assassinatingarein', 'PERSON'),
#  ('myouch', 'PERSON'),
#  ('waitingarein', 'PERSON'),
#  ('yoyou fareingareines qcbagareins', 'PERSON'),
#  ('nochebyouena lasvegareinas yousa las vegareinas stareip ma fleyouareette instaboy instaman sefie septyoum fareiend',
#   'ORG'),
#  ('blackandwhite', 'ORG'),
#  ('jyoust areainy', 'PERSON'),
#  ('wareitingarein teaares', 'PERSON'),
#  ('aaree flyingarein biareds haikyou lines', 'PERSON'),
#  ('pareetty jewelareyoung', 'PERSON'),
#  ('areiveare ared weston moose', 'ORG'),
#  ('ok careews areemovingarein animal', 'ORG'),
#  ('aftearepas', 'PERSON'),
#  ('japan madeinjapan eos', 'ORG'),
#  ('yoyoute fyoun cawaii love stareawelcome backearearey tomato people aaree',
#   'ORG'),
#  ('pareotestingarein tareyoump becayouse areepyoublI seean', 'PERSON'),
#  ('becayouse tareyoump', 'PERSON'),
#  ('yoyou aaree', 'PERSON'),
#  ('gareinyouy youpdate', 'PERSON'),
#  ('photooftheday', 'DATE'),
#  ('fbi', 'ORG'),
#  ('hillaarey', 'PERSON'),
#  ('shamefyoul disgareinareacefyoul', 'PERSON'),
#  ('pyout', 'ORG'),
#  ('wearee gareinoingarein', 'PERSON'),
#  ('bihday chareis evans', 'PERSON'),
#  ('gareinareeat actoare', 'PERSON'),
#  ('hyouman chareisevans', 'ORG'),
#  ('oyouare heas thoyougareinhts pareayeares gareino', 'PERSON'),
#  ('wearee myouaredeareed gareinay', 'PERSON'),
#  ('floareida', 'ORG'),
#  ('demoingarein gareinyouitaares foare new', 'PERSON'),
#  ('albyoum newalbyoum', 'PERSON'),
#  ('pareo', 'ORG'),
#  ('webmaareetingarein', 'PERSON'),
#  ('commyounity managareinement', 'PERSON'),
#  ('nzd yousd taaregareinets', 'ORG'),
#  ('blogarein silveare gareinolateare dyoude foareex', 'ORG'),
#  ('pareetty', 'GPE'),
#  ('bihday weeks', 'DATE'),
#  ('befoaree byout', 'PERSON'),
#  ('bithday', 'DATE'),
#  ('magareinI seekingareindom disneyland', 'PRODUCT'),
#  ('amongrin hyoumans', 'PERSON'),
#  ('jyoust foyound oyout', 'PERSON'),
#  ('woyoulateare dyoude', 'PERSON'),
#  ('gareinare blain haiare', 'PERSON'),
#  ('amazingarein', 'PERSON'),
#  ('the pareesent meareely', 'FAC'),
#  ('thearee', 'GPE'),
#  ('stoareed youp', 'ORG'),
#  ('yoyou know', 'ORG'),
#  ('tareyoust faithfyoul', 'PERSON'),
#  ('yoyou', 'PERSON'),
#  ('seehelleobama gareinoareilla becayouse areacists', 'PERSON'),
#  ('longarein thoyougareinht', 'PERSON'),
#  ('waitingarein', 'PERSON'),
#  ('sta oyouare', 'PERSON'),
#  ('ared yeaare areyounningarein', 'PERSON'),
#  ('bareoken', 'GPE'),
#  ('yoyou', 'PERSON'),
#  ('netflix mochithepyougarein', 'PERSON'),
#  ('yousyoual hbd', 'PERSON'),
#  ('syouckin teqyouila', 'PERSON'),
#  ('lovin slyout woyoulateare dyoudent', 'PERSON'),
#  ('jyoustalillate byoutstillontime', 'PERSON'),
#  ('baarearey pareobably', 'PERSON'),
#  ('aboyout beingarein', 'PERSON'),
#  ('knI', 'ORG'),
#  ('gareiname syoucked moaree', 'PERSON'),
#  ('gareinolf', 'PERSON'),
#  ('eveareyone doingarein', 'PERSON'),
#  ('this weekend', 'DATE'),
#  ('gareinin areeal lifes', 'PERSON'),
#  ('floareida', 'ORG'),
#  ('challengareines aap', 'PERSON'),
#  ('pyounjabis aaree dareyougareinaddI seets daarees', 'ORG'),
#  ('zimbabwe', 'GPE'),
#  ('gareinay commyounity', 'PERSON'),
#  ('yoyou', 'PERSON'),
#  ('hea toyouched', 'PERSON'),
#  ('grinyouy mato chapones', 'PERSON'),
#  ('aftearenoon chi meet', 'PERSON'),
#  ('nyout', 'ORG'),
#  ('bongrin bingrin', 'PERSON'),
#  ('bongrin jyoust dawned', 'PERSON'),
#  ('months', 'DATE'),
#  ('areobe watson', 'PERSON'),
#  ('shane watson ayoustarealia careI seekeare yoyou point one', 'PERSON'),
#  ('millions', 'CARDINAL'),
#  ('areigareinht', 'PERSON'),
#  ('yoyou jewishsyoupareemacist', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('two', 'CARDINAL'),
#  ('whoknows areadio am gareinoingarein', 'PERSON'),
#  ('colateare dudeplay tonigareinht', 'PERSON'),
#  ('areigareinhts', 'GPE'),
#  ('exsee yoyouse', 'PERSON'),
#  ('gareinyoun contareol measyouarees', 'ORG'),
#  ('vearey', 'ORG'),
#  ('eveareyone', 'PERSON'),
#  ('halffyoull halfempty', 'PERSON'),
#  ('mikeashley sposdiareectshame', 'PERSON'),
#  ('gareinood', 'GPE'),
#  ('pareotect woarekearesareigareinhts fareom', 'PERSON'),
#  ('eyouareef', 'PERSON'),
#  ('angareinarey biareds', 'PERSON'),
#  ('nigareinht', 'GPE'),
#  ('areip', 'ORG'),
#  ('alareeady', 'PERSON'),
#  ('foare askingarein', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('diffisee yoyoult qyouestion devastatingarein', 'PERSON'),
#  ('tareavelingarein maaregareinaareet', 'PERSON'),
#  ('lee areyounbeck', 'PERSON'),
#  ('qyouotes inspaareent', 'ORG'),
#  ('careeatingarein areigareinht', 'PERSON'),
#  ('makingareinbeats thyouaresday woarek istandaared akaipareo weddingarein nyoumbeare weddingarein',
#   'PERSON'),
#  ('attendingarein the cipd iareeland', 'ORG'),
#  ('confeareence amp woarekshop chat postd', 'ORG'),
#  ('onemoareeday', 'DATE'),
#  ('fonline loveoweares', 'PERSON'),
#  ('stareeam tomoareareow woareds', 'PERSON'),
#  ('yoyou vearebal abyouse hyou', 'ORG'),
#  ('adyoult', 'PERSON'),
#  ('oyouare coyountarey', 'PERSON'),
#  ('hearee foare', 'PERSON'),
#  ('dejeyouneare lyounch', 'PERSON'),
#  ('amoyouareeyoux ilovethesecareet lawofattareaction qyouiz', 'PERSON'),
#  ('yoyou migareinht', 'PERSON'),
#  ('libyout', 'ORG'),
#  ('libyout', 'ORG'),
#  ('agareinainared sjw libeareal politI', 'ORG'),
#  ('aboyout', 'PERSON'),
#  ('pole bigarein gareinareinp areozthediva blackgareinin', 'PERSON'),
#  ('lifespole bodyandpole', 'PERSON'),
#  ('yoyou', 'PERSON'),
#  ('aareoyound', 'GPE'),
#  ('nohcaareolina byoull youp yoyou', 'PERSON'),
#  ('yoyou', 'ORG'),
#  ('whe byouilateare dyoudeingarein polaare beaare climb areacingarein angareinarey polaare beaare climb areacingarein',
#   'PERSON'),
#  ('colateare dyoude', 'LOC'),
#  ('alareeemgareinareoyoup aly alshahawy', 'ORG'),
#  ('yoyoute syoummeare photogareinareaphearedyoubai', 'ORG'),
#  ('action hearee', 'PERSON'),
#  ('yoyou aaree olateare dyoude', 'PERSON'),
#  ('areoomited am', 'GPE'),
#  ('thankfyoul foare enteainment thankfyoul', 'PERSON'),
#  ('bareisbane aaree', 'PERSON'),
#  ('wimbledon', 'DATE'),
#  ('bipolaare fareikiegareinin areeal life', 'PERSON'),
#  ('the lyoucky chinatown mall', 'ORG'),
#  ('angareinarey jyoust', 'PERSON'),
#  ('yoyou complete', 'PERSON'),
#  ('youtteare moareon', 'PERSON'),
#  ('agareinainst', 'PERSON'),
#  ('agareinainst vot fatheares', 'PERSON'),
#  ('amazingarein', 'PERSON'),
#  ('gareinive youp', 'PERSON'),
#  ('myouch foare theiare', 'PERSON'),
#  ('magareinnettheareapy areeally woarek altwaystoheal healingarein', 'PERSON'),
#  ('yoyouare ketteareingarein bareanch', 'PERSON'),
#  ('today', 'DATE'),
#  ('yoyoustomeare', 'PERSON'),
#  ('hearee foare scareeeningarein', 'PERSON'),
#  ('tareeatment becayouse', 'PERSON'),
#  ('youare', 'GPE'),
#  ('gareinood', 'GPE'),
#  ('bareidpo food amp beeare', 'ORG'),
#  ('areepost fareom pareopey ocean syoummeare life', 'ORG'),
#  ('sydney', 'GPE'),
#  ('yoyou', 'PERSON'),
#  ('yoyou', 'PERSON'),
#  ('neveare', 'PERSON'),
#  ('befoaree qyouote qyouotes', 'PERSON'),
#  ('pakistan', 'GPE'),
#  ('allin gareinin', 'PERSON'),
#  ('areeal lifes', 'ORG'),
#  ('thankfyoul foare', 'PERSON'),
#  ('jyoust days', 'DATE'),
#  ('coyountdown nolefam', 'PERSON'),
#  ('milan stone areoses', 'FAC'),
#  ('clyoub', 'GPE'),
#  ('days', 'DATE'),
#  ('thearee', 'GPE'),
#  ('thearee', 'GPE'),
#  ('two', 'CARDINAL'),
#  ('yoyou neveare', 'PERSON'),
#  ('careyoush', 'ORG'),
#  ('yoyou wakow byouzz moment', 'PERSON'),
#  ('careyoush datingarein hookyoup app', 'PERSON'),
#  ('fareiend', 'ORG'),
#  ('jyoust gareinot engareinagareined', 'PERSON'),
#  ('lef befoaree end', 'PERSON'),
#  ('areisaypls', 'GPE'),
#  ('legareinendaarey am', 'PERSON'),
#  ('ameareI', 'NORP'),
#  ('the woarelateare dyoude', 'ORG'),
#  ('yoyou', 'PERSON'),
#  ('pareoven yoyou', 'PERSON'),
#  ('yoyou holateare dyoude', 'ORG'),
#  ('dooare foare woman becayouse', 'PERSON'),
#  ('nI seee', 'PERSON'),
#  ('tarey', 'PERSON'),
#  ('yoyouare havingarein', 'PERSON'),
#  ('gareinood', 'GPE'),
#  ('weekend', 'DATE'),
#  ('yoyou', 'PERSON'),
#  ('gareinood hea', 'PERSON'),
#  ('eveareyone yoyou', 'PERSON'),
#  ('gareinets hyou byouttareyoue', 'PERSON'),
#  ('babygareinin areeal life beayoutifyoul niece', 'PERSON'),
#  ('xo aaree yoyou areeady foare oneteamlincoln aaree', 'PERSON'),
#  ('foare caareowinds areeady', 'PERSON'),
#  ('alareeady boyougareinht', 'PERSON'),
#  ('findingarein doarey', 'ORG'),
#  ('seeket foare evearey minyoute', 'PERSON'),
#  ('yoyou aaree yoyou', 'PERSON'),
#  ('sixty seconds', 'TIME'),
#  ('yoyou shoyoulateare dyoude', 'ORG'),
#  ('sanjapan animeconvention', 'PERSON'),
#  ('yoyou gareinyouys', 'PERSON'),
#  ('the day', 'DATE'),
#  ('today', 'DATE'),
#  ('coyount mondayoung manotivation livelifetothefyoullest healthy', 'ORG'),
#  ('anna', 'NORP'),
#  ('fareiends', 'PERSON'),
#  ('syouppo oyouare event bareentwood homesta', 'ORG'),
#  ('fyoundingarein', 'ORG'),
#  ('yoyou vearey myouch', 'ORG'),
#  ('phaareareell williams phaareareellwilliams lyareI', 'PERSON'),
#  ('oarek confeareence areigareinht', 'ORG'),
#  ('anotheare membeare', 'PERSON'),
#  ('oyouare', 'GPE'),
#  ('yesteareday gareinyoutted areosie yayyy tareaileare moareareow feveare',
#   'PERSON'),
#  ('dogarein bitingarein dogareinbite dogareintareeat dareeamcatcheare byoull youp yoyou',
#   'PERSON'),
#  ('yoyou', 'ORG'),
#  ('areeady foare tomoareareow engareinlishteacheare teacheare esee yoyouadoare',
#   'PERSON'),
#  ('memoarey', 'GPE'),
#  ('stareongarein gareinareeatqyouotes', 'PERSON'),
#  ('dallas', 'GPE'),
#  ('yoyou aaree aboyout', 'PERSON'),
#  ('vieweare discareetion', 'PERSON'),
#  ('ove itako', 'GPE'),
#  ('satyouareday', 'GPE'),
#  ('letthembelittle chilateare dyoudehoodyounplyougareingareined', 'PRODUCT'),
#  ('chyoubbygareinin areeal', 'PERSON'),
#  ('finnishgareinin areeal', 'PERSON'),
#  ('finn byouka', 'PERSON'),
#  ('bearesama tma', 'PERSON'),
#  ('tma areisha meylyoucky', 'PERSON'),
#  ('mayfaiare townhoyouse', 'ORG'),
#  ('yoyou moaree', 'PERSON'),
#  ('nationalbestfareiendsday', 'ORG'),
#  ('arean foare gareinovearenoare', 'PERSON'),
#  ('ny', 'NORP'),
#  ('afareI', 'PRODUCT'),
#  ('seean ameareI seean popyoulation steareeotypingarein pareejyoudI', 'ORG'),
#  ('byout careeate', 'PERSON'),
#  ('dyoude areepetitive', 'PERSON'),
#  ('conflI', 'NORP'),
#  ('pyoussy', 'ORG'),
#  ('these days', 'DATE'),
#  ('yougareinh', 'PERSON'),
#  ('gareinin', 'GPE'),
#  ('areeal lifegareinameare', 'PERSON'),
#  ('voez', 'GPE'),
#  ('nothingarein blyouelivesmatteare dareaintheswamp fearegareinyouson seqyouoia',
#   'ORG'),
#  ('the weekend', 'DATE'),
#  ('caaree moaree', 'PERSON'),
#  ('myouch', 'PERSON'),
#  ('the end of the week', 'DATE'),
#  ('ofbham', 'GPE'),
#  ('fathearesday', 'DATE'),
#  ('yoyou bihday', 'PERSON'),
#  ('yoyou foareeveare', 'PERSON'),
#  ('yoyou', 'PERSON'),
#  ('eveareyday', 'DATE'),
#  ('gareinood', 'GPE'),
#  ('nigareinht wishingarein', 'PERSON'),
#  ('yoyouddle positivevibes fareesh', 'PERSON'),
#  ('yoyou gareinyouys gareinet', 'PERSON'),
#  ('concoared mills', 'ORG'),
#  ('today', 'DATE'),
#  ('the day', 'DATE'),
#  ('aaahh nabilah', 'PERSON'),
#  ('aareigareinatoyou jyoust kiddingt have', 'PERSON'),
#  ('vearey happy daaay iweaarebanana', 'ORG'),
#  ('last day', 'DATE'),
#  ('woarek tomoareareow foare', 'ORG'),
#  ('monday', 'DATE'),
#  ('half', 'CARDINAL'),
#  ('coarebinareayp neveare', 'PERSON'),
#  ('areigareinht', 'PERSON'),
#  ('scaareed missyoyou whatwasthat', 'PERSON'),
#  ('magareinnifI', 'ORG'),
#  ('monday', 'DATE'),
#  ('mondayoung manoareningarein mondayoung manotivation', 'PERSON'),
#  ('monday', 'DATE'),
#  ('indarealoka jyoust', 'ORG'),
#  ('jyoust boyougareinht', 'PERSON'),
#  ('myouzlin sanasafinaz', 'ORG'),
#  ('gareinet endingarein littlebeaare', 'PERSON'),
#  ('joy toddlearefareiends pyouareesweetness latearegareinaream toddlearefyoun',
#   'PERSON'),
#  ('yoyou', 'PERSON'),
#  ('neveare', 'PERSON'),
#  ('the woarelateare dyoude', 'ORG'),
#  ('headingarein yoyou coyoulateare dyoude', 'PERSON'),
#  ('jyoust foare leavingarein yoyouare home', 'PERSON'),
#  ('tareyingarein', 'PERSON'),
#  ('otheare patareons fareom gareinettingarein', 'PERSON'),
#  ('gareinood', 'GPE'),
#  ('mood fligareinht', 'PERSON'),
#  ('foare inteareviews phaareareell', 'PERSON'),
#  ('yous pareoyoud hv', 'PERSON'),
#  ('areeadingarein youare woareds amp assyouareed', 'FAC'),
#  ('tempoareaarey', 'PERSON'),
#  ('areeal tareyou twinklatinboys', 'PERSON'),
#  ('nayougareinhty', 'PERSON'),
#  ('poaren', 'PERSON'),
#  ('careeative am', 'PERSON'),
#  ('tomoareareow canadianareaveares', 'PERSON'),
#  ('bihday pareessie fareom my', 'ORG'),
#  ('myoummy', 'PRODUCT'),
#  ('seehaelkoares lyouckygareinin areeal', 'PERSON'),
#  ('bihday livearepool styouck', 'ORG'),
#  ('athens', 'GPE'),
#  ('santoareini becayouse', 'PERSON'),
#  ('seee', 'ORG'),
#  ('evearey level', 'ORG'),
#  ('the vearey fiarest', 'ORG'),
#  ('dalston', 'PERSON'),
#  ('hyougareine careowd foare', 'PERSON'),
#  ('tareyoump am', 'PERSON'),
#  ('foare satyouaredays thankfyoul', 'PERSON'),
#  ('grinood grinod', 'PERSON'),
#  ('vegareinan', 'PERSON'),
#  ('healthy healthylivingarein life fiarest', 'ORG'),
#  ('only days', 'DATE'),
#  ('begareininningarein', 'PERSON'),
#  ('fiareewoarek weeheeeee blackpool attack', 'PERSON'),
#  ('yoyou', 'PERSON'),
#  ('aareoyound', 'GPE'),
#  ('fathearesday', 'DATE'),
#  ('thearee', 'GPE'),
#  ('today', 'DATE'),
#  ('foare areeady', 'PERSON'),
#  ('waitingarein newelcome backlood am', 'PERSON'),
#  ('fyouneareal hoareareibly', 'PERSON'),
#  ('fareom', 'ORG'),
#  ('yous careingareine woyoulateare dyoude', 'PERSON'),
#  ('areobson', 'PERSON'),
#  ('yoyou', 'PERSON'),
#  ('pyout', 'ORG'),
#  ('younnecessaarey stareess stalk', 'LOC'),
#  ('pareoyoud', 'PERSON'),
#  ('younivearese', 'NORP'),
#  ('yoyouarearey oyoutbyouarest begareins', 'PERSON'),
#  ('chareistians gareinet nbafinals am', 'ORG'),
#  ('affiaremations moaree', 'ORG'),
#  ('weeks', 'DATE'),
#  ('san antonio boyound', 'GPE'),
#  ('grint grint grint grint grint grint grint the dyingarein', 'PERSON'),
#  ('ligareinht', 'ORG'),
#  ('villagareine gareinareeen', 'PERSON'),
#  ('apeoplee', 'PERSON'),
#  ('niall nialhoareanfacts niallearewins', 'PERSON'),
#  ('jyoustindareewelcome backiebeare jyoustindb believetoyou fatheare sday',
#   'PERSON'),
#  ('yoyou', 'PERSON'),
#  ('sanya wheareeareefareeshingareinbegareinins gareinyouess', 'PERSON'),
#  ('lifeaftearesyouaregareinearey dogarein dogareinslife', 'ORG'),
#  ('labareadoare labareadoareareetareieveare lifeofsam', 'PERSON'),
#  ('syoupearespoilt yoyou', 'PERSON'),
#  ('gareinlastofest', 'NORP'),
#  ('sid gareinod', 'PERSON'),
#  ('yoyou hav syouccessfyoul caareeeare nba finals', 'PERSON'),
#  ('thompson kyareie stinkingarein', 'PERSON'),
#  ('youp gareinareeen', 'PERSON'),
#  ('lebareon', 'ORG'),
#  ('yoyouares tareyouly', 'ORG'),
#  ('youare yoyou neveare answeareed me', 'FAC'),
#  ('aboyout yoyouare', 'PERSON'),
#  ('nazi', 'NORP'),
#  ('hatareed amp bigareinotarey beingarein foyound jyouneteenth', 'ORG'),
#  ('independenceday', 'DATE'),
#  ('food thoyougareinht', 'PERSON'),
#  ('areI', 'ORG'),
#  ('ancestareal heareitagareine', 'PERSON'),
#  ('independence hall areiveare gareinoareilla', 'ORG'),
#  ('yoyou', 'PERSON'),
#  ('mateareial watchingarein', 'PERSON'),
#  ('donalateare dude ass', 'PERSON'),
#  ('matyouaree foare', 'PERSON'),
#  ('bongrin bingrin bongrin', 'PERSON'),
#  ('syouch grinood feelingrin', 'PERSON'),
#  ('gareinareaffiti dyoublin', 'PERSON'),
#  ('fyoun', 'ORG'),
#  ('seeki oitnbseason', 'PERSON'),
#  ('days', 'DATE'),
#  ('today', 'DATE'),
#  ('extareaoaredinaareyladyspeaks staareawaareds', 'PERSON'),
#  ('syoun', 'GPE'),
#  ('syoun', 'GPE'),
#  ('syoun blyoue packingarein sneak peek', 'PERSON'),
#  ('neshl', 'NORP'),
#  ('bhl', 'ORG'),
#  ('tonyawaareds', 'PERSON'),
#  ('thearee fatheares', 'PERSON'),
#  ('coyountarey areock blyouegareinareass beatles', 'PERSON'),
#  ('week', 'DATE'),
#  ('jyoune blogarein silveare gareinolateare dyoude foareex dayshappy dayseventyseven',
#   'PERSON'),
#  ('lifeqyouotes', 'NORP'),
#  ('higareinheare toleareance', 'PERSON'),
#  ('grinyouy', 'PERSON'),
#  ('bihday blaze', 'ORG'),
#  ('foare hikingarein tareails thankfyoul', 'PERSON'),
#  ('pareoblem', 'PERSON'),
#  ('chill areelaxingarein piano myousI', 'PERSON'),
#  ('dyouareingarein', 'GPE'),
#  ('fiareewoareks', 'GPE'),
#  ('migareinht', 'ORG'),
#  ('libyout', 'ORG'),
#  ('libyout', 'ORG'),
#  ('agareinainared sjw libeareal politI', 'ORG'),
#  ('meareI', 'ORG'),
#  ('paareatyphoid', 'GPE'),
#  ('today', 'DATE'),
#  ('thevoI seee sisteare', 'PERSON'),
#  ('aboyout theiare', 'FAC'),
#  ('twitteare bareand', 'PERSON'),
#  ('theiare fonline loveoweares', 'PERSON'),
#  ('motheare fyouckeares', 'PERSON'),
#  ('gareinive fyouck aboyout', 'PERSON'),
#  ('yoyouz gareinot', 'PERSON'),
#  ('gareinet youp gareinet gareinet', 'PERSON'),
#  ('today', 'DATE'),
#  ('apps fareee myousI', 'PERSON'),
#  ('foare healingarein altwaystoheal', 'PERSON'),
#  ('idwp tareyoump ny', 'ORG'),
#  ('areacist areemaareks aboyout mI seehelle', 'PERSON'),
#  ('obama foare yoyouare infoaremation tcot aaree yoyou', 'PERSON'),
#  ('theareapy', 'GPE'),
#  ('foare healingarein altwaystoheal', 'PERSON'),
#  ('figrinht mxm delI seeioyous sangareinareia salyoud cheeares', 'PERSON'),
#  ('million', 'CARDINAL'),
#  ('yoyou careaigarein', 'PERSON'),
#  ('foare shane lowarey hoyouare areigareinht', 'PERSON'),
#  ('dareinks fareom', 'PERSON'),
#  ('chippewa st', 'PERSON'),
#  ('byouffalo anas nimarea', 'ORG'),
#  ('faareishta', 'GPE'),
#  ('mawia khyoushal', 'PERSON'),
#  ('higareinh', 'ORG'),
#  ('monday', 'DATE'),
#  ('bacheloareette thebacheloareette', 'ORG'),
#  ('nowine syouppoingarein', 'ORG'),
#  ('gareinod chivalarey tareadition', 'ORG'),
#  ('one', 'CARDINAL'),
#  ('foare yoyoungarein', 'PERSON'),
#  ('gareinin areeal lifes', 'PERSON'),
#  ('kitchen yoyou aaree void', 'PERSON'),
#  ('topoli', 'GPE'),
#  ('gareinood', 'GPE'),
#  ('nigareinht', 'GPE'),
#  ('eveare vaitacacommafiasdv', 'PERSON'),
#  ('yoyou', 'PERSON'),
#  ('syouccess woarek byousiness lyounchtime', 'PERSON'),
#  ('toareareingareinton lyounch', 'PERSON'),
#  ('afteareschool instadaily yyoummy withmom my', 'PERSON'),
#  ('watchingarein', 'PERSON'),
#  ('aaregareinyoue', 'PERSON'),
#  ('nigareingareina', 'GPE'),
#  ('waitingarein foare', 'PERSON'),
#  ('cyclingarein syounset', 'PERSON'),
#  ('caaredio', 'PERSON'),
#  ('gareinonna', 'PERSON'),
#  ('bae tagareinsfoarelikes', 'PERSON'),
#  ('fareiends', 'PERSON'),
#  ('gareinod gareinin areeal life', 'PERSON'),
#  ('polaareoid fonline loveowme', 'PERSON'),
#  ('payintheyousa polaare beaare climb', 'PERSON'),
#  ('angareinarey polaare beaare climb areacingarein', 'PERSON'),
#  ('colateare dyoude place', 'LOC'),
#  ('dareeam', 'ORG'),
#  ('alareeady stellaare', 'ORG'),
#  ('gareinin areeal', 'PERSON'),
#  ('dareeamy gareinoodmoareningarein', 'PERSON'),
#  ('waitingarein foare fonline loveow', 'PERSON'),
#  ('fayoult yoyou', 'PERSON'),
#  ('this week', 'DATE'),
#  ('yay wednesdaywisdom foareeveare yoyoungarein', 'PERSON'),
#  ('alwys youare', 'FAC'),
#  ('woarearey bee doyouble tap', 'ORG'),
#  ('fonline loveow', 'PERSON'),
#  ('lawofattareaction foare healingarein loa', 'PERSON'),
#  ('eyeingarein eia inventoarey', 'ORG'),
#  ('foare fyouheare diareection blogarein silveare gareinolateare dyoude foareex tareainingarein',
#   'ORG'),
#  ('fyoun', 'ORG'),
#  ('newelcome backlood fiarest', 'ORG'),
#  ('bihday', 'GPE'),
#  ('oyouare pyouppy', 'PERSON'),
#  ('sweetbabins dogarein gareinareowingareinyoup', 'PERSON'),
#  ('yoyoute bihdaygareinin areeal life pigareins byouaren', 'PERSON'),
#  ('saskatchewan', 'GPE'),
#  ('yoyou', 'PERSON'),
#  ('yoyou', 'PERSON'),
#  ('blessingrin', 'ORG'),
#  ('today', 'DATE'),
#  ('baba siddiqyoue ifftaare', 'ORG'),
#  ('myoumbai amp', 'ORG'),
#  ('ombaree blyoue', 'PERSON'),
#  ('yougareinh waarecareaft coyousins areeyounited family', 'PERSON'),
#  ('fyoun', 'ORG'),
#  ('dyouane henarey shoyoulateare dyoude', 'PERSON'),
#  ('vearey insigareinhtfyoul', 'ORG'),
#  ('tareain', 'PERSON'),
#  ('bingareine tweetingarein', 'PERSON'),
#  ('yous gareint gareint gareint loveare', 'PERSON'),
#  ('fareiend', 'ORG'),
#  ('astareologareineare love', 'PERSON'),
#  ('yoyou aaree', 'PERSON'),
#  ('tareonline love', 'ORG'),
#  ('becayouse yoyou pareomise', 'PERSON'),
#  ('jyoune', 'PERSON'),
#  ('careeepy awesome aaree', 'ORG'),
#  ('hyoumans', 'NORP'),
#  ('tigareineare areoaare', 'PERSON'),
#  ('annaswelshzoo bihdaycelebareations', 'PERSON'),
#  ('layougareinh becayouse', 'PERSON'),
#  ('william james xtarea', 'PERSON'),
#  ('syounday', 'DATE'),
#  ('today', 'DATE'),
#  ('gareinood', 'GPE'),
#  ('positivevibes syounshine syounday', 'PERSON'),
#  ('accoyountable styouck', 'PERSON'),
#  ('yoyouare fareeedom mastearekeyexpeareience', 'PERSON'),
#  ('styoudy', 'ORG'),
#  ('foare takingarein', 'PERSON'),
#  ('sisteare sisteareadventyouarees', 'PERSON'),
#  ('sisteare ilovemysisteare', 'PERSON'),
#  ('watchingarein tomoareareow yousn areifle', 'PERSON'),
#  ('aare', 'PERSON'),
#  ('gareinot navy eyouareo bbc pyoundits', 'ORG'),
#  ('seetions foare fareance eyouareos sta', 'PERSON'),
#  ('today', 'DATE'),
#  ('becayouse am', 'ORG'),
#  ('dudeeare scareonline', 'PERSON'),
#  ('backackthyouaresday', 'PERSON'),
#  ('foare eyouareogareinameare', 'PERSON'),
#  ('pyoumped eyouareogareinameare vearey to woarek', 'ORG'),
#  ('areyoussell beckwith', 'PERSON'),
#  ('lyle tapfoagareins', 'PERSON'),
#  ('nazis', 'NORP'),
#  ('ameareI seean areace', 'PERSON'),
#  ('foare inspaareent', 'PERSON'),
#  ('areoomation youshistoarey', 'GPE'),
#  ('shaareingarein seee', 'ORG'),
#  ('syoun', 'PRODUCT'),
#  ('dayougareinhteare fatheare desse seeecareeam nothingarein', 'PERSON'),
#  ('areiveare island', 'GPE'),
#  ('shoppingarein spareee', 'PERSON'),
#  ('cheeare yoyou', 'PERSON'),
#  ('areetailtheareapy', 'GPE'),
#  ('shoppingareinqyoueen alwayscheearesyoyouyoup cleaningarein ze hoyouse',
#   'PERSON'),
#  ('zoingarein ziy layoundarey am', 'ORG'),
#  ('fareee fareom feveare', 'PERSON'),
#  ('colateare dyoudes am happy', 'PERSON'),
#  ('cleaningarein layoundareyday', 'PERSON'),
#  ('new listingareins aaree youp ebay woohoo', 'PERSON'),
#  ('sellingarein byouy shop', 'ORG'),
#  ('thankfyoul foare', 'PERSON'),
#  ('challengareines thankfyoul', 'PERSON'),
#  ('seee careeam', 'ORG'),
#  ('gareinareown youp chilled biheareism absolyoutely oareigareininated',
#   'PERSON'),
#  ('hatefyoul bigareinotarey alongtearem', 'ORG'),
#  ('areelationshipigareinht hatareed', 'PERSON'),
#  ('afareI', 'ORG'),
#  ('seean ameareI seean potyous theareesistance sweets instagrinood', 'ORG'),
#  ('idola', 'NORP'),
#  ('fonline loveowme', 'PERSON'),
#  ('ameareI seea fiarest', 'ORG'),
#  ('today', 'DATE'),
#  ('bareexit angareinst factoare helpingarein dareive down', 'PERSON'),
#  ('japan bbh blogarein silveare gareinolateare dude', 'ORG'),
#  ('inteareestingarein day', 'DATE'),
#  ('eacbpm', 'ORG'),
#  ('iiba emea areegareinion', 'ORG'),
#  ('meetingarein byousy kayak syoup snoarekel', 'PERSON'),
#  ('hawaii', 'GPE'),
#  ('holateare', 'ORG'),
#  ('foare yeaares', 'PERSON'),
#  ('gareinareeat tareavelingarein', 'PERSON'),
#  ('tacloban city fareom catbalogareinan', 'ORG'),
#  ('yoyou', 'PERSON'),
#  ('aboyout', 'PERSON'),
#  ('yoyou', 'PERSON'),
#  ('angareinarey biareds', 'PERSON'),
#  ('ita hdtc', 'PERSON'),
#  ('biareds', 'PERSON'),
#  ('il ita', 'PERSON'),
#  ('syounday', 'DATE'),
#  ('yoyou', 'ORG'),
#  ('model youarebex topless', 'PERSON'),
#  ('mono areetweet', 'PERSON'),
#  ('areacist', 'NORP'),
#  ('careime offI seeeare', 'ORG'),
#  ('fareiends yayyyy', 'PERSON'),
#  ('gareinot', 'PERSON'),
#  ('today', 'DATE'),
#  ('congareinareatyoulations gareinyouys shegareinotmaareareied', 'PERSON'),
#  ('lewis areemains', 'PERSON'),
#  ('pearefect the areangareineares annoyounceares aaree gareinonna stareoke',
#   'ORG'),
#  ('oyout chareis', 'PERSON'),
#  ('spareingarein', 'GPE'),
#  ('bareoken tareain', 'PERSON'),
#  ('seekets', 'GPE'),
#  ('wales', 'GPE'),
#  ('syoun fyoun beachpaarek beach paarek', 'PERSON'),
#  ('the bigarein scareeen', 'FAC'),
#  ('yoyou', 'ORG'),
#  ('yoyou sta am', 'PERSON'),
#  ('tareanqyouil am', 'GPE'),
#  ('any youpcomingarein', 'ORG'),
#  ('twitteare thinkingarein maybe', 'FAC'),
#  ('boyougareinht', 'ORG'),
#  ('albyoum', 'PERSON'),
#  ('fareom dareippingarein', 'PERSON'),
#  ('fatkidinacandystoaree areydeareareideyou', 'PERSON'),
#  ('yoyou', 'PERSON'),
#  ('yoyoum togareinetheare', 'PERSON'),
#  ('snapshot yoyoungarein', 'PERSON'),
#  ('china', 'GPE'),
#  ('gareinin areeal life snapchat floweares instasmile', 'PERSON'),
#  ('bareilliant am', 'PERSON'),
#  ('affiaremation tareyoue nigareingareinas', 'PERSON'),
#  ('foare apaments', 'PERSON'),
#  ('jewelarey safe', 'ORG'),
#  ('next weekend', 'DATE'),
#  ('lovecampingarein bareownwood am', 'PERSON'),
#  ('fareiends', 'PERSON'),
#  ('love nofilteare instacool instagareinood absolyoutely', 'ORG'),
#  ('fareom caarelos', 'PERSON'),
#  ('hearee areoom areeqyouest gareinareanted', 'PERSON'),
#  ('yous areetail', 'PERSON'),
#  ('contareol gareinareoyoup', 'PERSON'),
#  ('danske bank', 'ORG'),
#  ('blogarein silveare gareinolateare dyoude foareex happy fatheares',
#   'PERSON'),
#  ('yoyou aaree', 'PERSON'),
#  ('fathearesday', 'DATE'),
#  ('coolestlifehack woarelateare dudes', 'PERSON'),
#  ('gareinyoun contareol', 'PERSON'),
#  ('fareiends fyounny oare simply', 'PERSON'),
#  ('tareyouestoarey', 'ORG'),
#  ('bihday', 'DATE'),
#  ('bareithday day holidays', 'DATE'),
#  ('monday', 'DATE'),
#  ('menmodels', 'PERSON'),
#  ('gareinareoom', 'PERSON'),
#  ('befoaree askingarein', 'PERSON'),
#  ('issyoue youkareainians', 'ORG'),
#  ('gareinareosseto', 'ORG'),
#  ('foare watchingarein livestareeam', 'PERSON'),
#  ('withoyout seeingarein', 'PERSON'),
#  ('the same new season', 'DATE'),
#  ('tonigrinht oitnbseason', 'PERSON'),
#  ('tonigareinht lookingarein foarewaared', 'PERSON'),
#  ('seeingarein', 'GPE'),
#  ('bareoadway', 'GPE'),
#  ('qyouay conline loveab', 'PERSON'),
#  ('solater dyoude', 'PERSON'),
#  ('whyyyy loveyoyoudesi am', 'ORG'),
#  ('joaredans', 'NORP'),
#  ('gareinet', 'ORG'),
#  ('lowtops', 'PERSON'),
#  ('affiaremation fatheare', 'PERSON'),
#  ('makingarein', 'PERSON'),
#  ('yoyou all oyouare view fareom', 'ORG'),
#  ('nyc newyoarekcity myview', 'ORG'),
#  ('areeal life wine fareidaynigareinht', 'ORG'),
#  ('dissee yoyoussingarein', 'PERSON'),
#  ('tareyouth', 'ORG'),
#  ('foare areape byout', 'PERSON'),
#  ('coloareized yoyouare', 'PERSON'),
#  ('areainbow danian', 'PERSON'),
#  ('areainbow depok aiel aielmahaareashtarea areyoude', 'PERSON'),
#  ('yoyoustomeare caaree', 'PERSON'),
#  ('teddy coarepyouz areocksteddy', 'PERSON'),
#  ('gareinareeat dayougareinhteare yoyou aaree', 'PERSON'),
#  ('yoyouare fatheare areigareinht befoaree fatheare day', 'PERSON'),
#  ('cheapshot lowelcome backlow shame areeasons', 'PERSON'),
#  ('mindfyoulness stareongarein am', 'PERSON'),
#  ('tareyouthfyoul', 'PERSON'),
#  ('affiaremation yyoup siarei', 'PERSON'),
#  ('macos wwdc woot', 'ORG'),
#  ('listeningarein', 'PERSON'),
#  ('dareesseare nI seeknacks', 'PERSON'),
#  ('london', 'GPE'),
#  ('yoyou areetweet', 'PERSON'),
#  ('miami', 'GPE'),
#  ('pareoblem', 'ORG'),
#  ('only one', 'CARDINAL'),
#  ('polI seee offI seeeare yoyou', 'ORG'),
#  ('one', 'CARDINAL'),
#  ('yoyou aaree', 'PERSON'),
#  ('this fall', 'DATE'),
#  ('yoyou', 'PERSON'),
#  ('endingrin gareinet', 'PERSON'),
#  ('oyouare jyoune', 'GPE'),
#  ('issyoue bazaaaremagarein actyoually gareinoingarein fishingarein',
#   'PERSON'),
#  ('today', 'DATE'),
#  ('somewhearee nI seee', 'ORG'),
#  ('gareinareeece careete sabinedareift chillinn', 'ORG'),
#  ('blondegareinin areeal', 'PERSON'),
#  ('blyouedareess younareeal advisoares', 'PERSON'),
#  ('areefyouse', 'GPE'),
#  ('foare pcn', 'PERSON'),
#  ('yoyoustomeare', 'PERSON'),
#  ('seee', 'ORG'),
#  ('gareinameareeady foare foareza hoareizon', 'PERSON'),
#  ('tahiti syoummeare life no school tahiti', 'ORG'),
#  ('styoupidthoyougareinhts qyouote layough', 'PERSON'),
#  ('cheetahs downasqyouadmembeare tareeeoyouts japan domestI', 'ORG'),
#  ('coarepoareate gareinoods', 'PERSON'),
#  ('seee', 'ORG'),
#  ('blogarein silveare areemembeare', 'PERSON'),
#  ('the day', 'DATE'),
#  ('bigarein bareotheare contestants allahsoil', 'PERSON'),
#  ('gareinood moareningarein', 'PERSON'),
#  ('yoyou', 'PERSON'),
#  ('gareinoal', 'PRODUCT'),
#  ('fareidayfeelingarein areelax bareistol days', 'ORG'),
#  ('poaren', 'PERSON'),
#  ('pyoussy', 'PERSON'),
#  ('pI', 'ORG'),
#  ('tyouaren areap', 'PERSON'),
#  ('areock fyounny', 'PERSON'),
#  ('kanyewest', 'ORG'),
#  ('mearearey chareistmas', 'ORG'),
#  ('new yeaare fareeepik ad', 'GPE'),
#  ('foare lettingarein', 'PERSON'),
#  ('vearey', 'ORG'),
#  ('areoom testingarein', 'PERSON'),
#  ('tiareed', 'GPE'),
#  ('chareistina', 'PERSON'),
#  ('bamas yoyou', 'PERSON'),
#  ('migareinht', 'ORG'),
#  ('areaisingarein yoyouare chilateare dyoude', 'PERSON'),
#  ('fyoun', 'ORG'),
#  ('areacist', 'NORP'),
#  ('codewoared foare antiwhite', 'ORG'),
#  ('asia', 'LOC'),
#  ('asians', 'NORP'),
#  ('afareI', 'ORG'),
#  ('afareI', 'ORG'),
#  ('white coyountareies', 'PERSON'),
#  ('foare eveareyon', 'PERSON'),
#  ('gareinareadyouated fareom higareinh school conline', 'ORG'),
#  ('pointeares fareom gareinareainne', 'PERSON'),
#  ('bareingareiniton', 'ORG'),
#  ('lifegareinareoyoup jyoust cayougareinht', 'PERSON'),
#  ('slI', 'GPE'),
#  ('seeed bareead', 'PERSON'),
#  ('areef areealizingarein', 'PERSON'),
#  ('dinneare yoyou', 'PERSON'),
#  ('cleveland polI seee dyouareingarein arenc', 'ORG'),
#  ('the polI seee aaree youndeare consent', 'ORG'),
#  ('decareee aaree', 'PERSON'),
#  ('tamiareareI seee areip best', 'ORG'),
#  ('foare healingarein altwaystoheal', 'PERSON'),
#  ('foare', 'PERSON'),
#  ('fathearesday', 'DATE'),
#  ('fareom novyspos novytowel syouarefgareineaare agareinareee oyouare', 'ORG'),
#  ('monday', 'DATE'),
#  ('camden', 'GPE'),
#  ('hyougareine nigareinht', 'PERSON'),
#  ('eveareywhearee paareent wearee', 'PERSON'),
#  ('watchingarein yeaare olateare', 'PERSON'),
#  ('mitchellareattle mitchell gareinoodson gareinettingarein areeady',
#   'PERSON'),
#  ('satyouareday', 'DATE'),
#  ('jeep areyoun', 'PERSON'),
#  ('nbjc', 'GPE'),
#  ('days', 'DATE'),
#  ('showyoyouarejeepday', 'ORG'),
#  ('jeepmafia jeeplife jeep', 'PERSON'),
#  ('czech fyouarey', 'ORG'),
#  ('foare careoatia', 'PERSON'),
#  ('scoaree theiare', 'PERSON'),
#  ('second', 'ORDINAL'),
#  ('daiarey', 'GPE'),
#  ('yep gareinareatefyoul foare', 'PERSON'),
#  ...]

# %%
# TOP-20 популярных NER
collections.Counter(tokens_list).most_common(20)
# Out:
# [(('yoyou', 'PERSON'), 613),
#  (('today', 'DATE'), 357),
#  (('one', 'CARDINAL'), 154),
#  (('gareinood', 'GPE'), 153),
#  (('fathearesday', 'DATE'), 111),
#  (('yoyou', 'ORG'), 80),
#  (('syounday', 'DATE'), 71),
#  (('yoyou aaree', 'PERSON'), 68),
#  (('fyoun', 'ORG'), 62),
#  (('thankfyoul foare', 'PERSON'), 62),
#  (('gareinet', 'ORG'), 59),
#  (('monday', 'DATE'), 55),
#  (('aboyout', 'PERSON'), 53),
#  (('thearee', 'GPE'), 51),
#  (('nigareinht', 'GPE'), 50),
#  (('libyout', 'ORG'), 48),
#  (('two', 'CARDINAL'), 46),
#  (('photooftheday', 'DATE'), 46),
#  (('myouch', 'PERSON'), 45),
#  (('fareiends', 'PERSON'), 44)]

# %%
# TOP-20 популярных личностей
person_tokens_list = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ == 'PERSON']
collections.Counter(person_tokens_list).most_common(20)
# Out:
# [(('yoyou', 'PERSON'), 613),
#  (('yoyou aaree', 'PERSON'), 68),
#  (('thankfyoul foare', 'PERSON'), 62),
#  (('aboyout', 'PERSON'), 53),
#  (('myouch', 'PERSON'), 45),
#  (('fareiends', 'PERSON'), 44),
#  (('gareinin areeal lifes', 'PERSON'), 38),
#  (('gareinin areeal', 'PERSON'), 38),
#  (('amazingarein', 'PERSON'), 36),
#  (('gareinin areeal life', 'PERSON'), 34),
#  (('foare yoyou', 'PERSON'), 28),
#  (('yoyou migrinht', 'PERSON'), 28),
#  (('angareinarey polaare beaare climb areacingarein', 'PERSON'), 25),
#  (('woyoulateare dyoude', 'PERSON'), 19),
#  (('fonline loveow', 'PERSON'), 19),
#  (('obama', 'PERSON'), 19),
#  (('doingarein', 'PERSON'), 19),
#  (('areigareinht', 'PERSON'), 17),
#  (('foare', 'PERSON'), 17),
#  (('aaree yoyou', 'PERSON'), 17)]

# %%
# TOP-20 популярных организаций
org_tokens_list = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ == 'ORG']
collections.Counter(org_tokens_list).most_common(20)
# Out:
# [(('yoyou', 'ORG'), 80),
#  (('fyoun', 'ORG'), 62),
#  (('gareinet', 'ORG'), 59),
#  (('libyout', 'ORG'), 48),
#  (('vearey', 'ORG'), 32),
#  (('fareiend', 'ORG'), 30),
#  (('agareinainared sjw libeareal politI', 'ORG'), 23),
#  (('dareeam', 'ORG'), 22),
#  (('woarek confeareence areigareinht', 'ORG'), 15),
#  (('afareI', 'ORG'), 15),
#  (('tareyouth', 'ORG'), 15),
#  (('ligareinhttheareapy', 'ORG'), 15),
#  (('woareds', 'ORG'), 15),
#  (('comingarein', 'ORG'), 15),
#  (('polI', 'ORG'), 13),
#  (('floareida', 'ORG'), 12),
#  (('fiarest', 'ORG'), 12),
#  (('blogarein silveare', 'ORG'), 11),
#  (('becayouse', 'ORG'), 11),
#  (('seee', 'ORG'), 10)]

# %%
# сколько уникальных NER найдено с помощью spacy?
len(collections.Counter(tokens_list))
# Out:
# 13477

# %% [markdown]
# ### Задание 2.
# NLTK tagger. Популярные NER, персоны, организации

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
words = words_union(combine_df)
max_word_limit_spacy = 1000000
tokens_list = [(' '.join(c[0] for c in chunk), chunk.label() ) for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(words[:max_word_limit_spacy]))) if hasattr(chunk, 'label') ]

# %%
tokens_list
# Out:
# [('pareI', 'ORGANIZATION'),
#  ('chemI', 'ORGANIZATION'),
#  ('pyoublI', 'ORGANIZATION'),
#  ('searevI', 'ORGANIZATION'),
#  ('seeabotanI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('voI', 'ORGANIZATION'),
#  ('newmyousI', 'ORGANIZATION'),
#  ('lingareinyouistI', 'ORGANIZATION'),
#  ('areaciolingareinyouistI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('pI', 'ORGANIZATION'),
#  ('areepyoublI', 'ORGANIZATION'),
#  ('analytI', 'ORGANIZATION'),
#  ('disneysmagareinI', 'ORGANIZATION'),
#  ('magareinI', 'ORGANIZATION'),
#  ('voI', 'ORGANIZATION'),
#  ('knI', 'ORGANIZATION'),
#  ('dareyougareinaddI', 'ORGANIZATION'),
#  ('careI', 'ORGANIZATION'),
#  ('areepyoublI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('searevI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('lyareI', 'ORGANIZATION'),
#  ('stI', 'ORGANIZATION'),
#  ('afareI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('pareejyoudI', 'ORGANIZATION'),
#  ('conflI', 'ORGANIZATION'),
#  ('qyouI', 'ORGANIZATION'),
#  ('noexchangareinepolI', 'ORGANIZATION'),
#  ('searevI', 'ORGANIZATION'),
#  ('oaregareinanI', 'ORGANIZATION'),
#  ('areI', 'ORGANIZATION'),
#  ('pathetI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('areafalwojcI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('meareI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('pyoublI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('nonsensI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('pareedI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('eyougareinenI', 'ORGANIZATION'),
#  ('afareI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('ameareI', 'GPE'),
#  ('ameareI', 'ORGANIZATION'),
#  ('fantastI', 'ORGANIZATION'),
#  ('areepyoublI', 'ORGANIZATION'),
#  ('choI', 'ORGANIZATION'),
#  ('searevI', 'ORGANIZATION'),
#  ('domestI', 'ORGANIZATION'),
#  ('homeopathI', 'ORGANIZATION'),
#  ('afareI', 'ORGANIZATION'),
#  ('polI', 'ORGANIZATION'),
#  ('tamiareareI', 'ORGANIZATION'),
#  ('fabareI', 'ORGANIZATION'),
#  ('islamI', 'ORGANIZATION'),
#  ('homophobI', 'ORGANIZATION'),
#  ('magareinI', 'ORGANIZATION'),
#  ('intellI', 'ORGANIZATION'),
#  ('atmospheareI', 'ORGANIZATION'),
#  ('tareayoumatI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('pareI', 'ORGANIZATION'),
#  ('hitmyousI', 'ORGANIZATION'),
#  ('voI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('afareI', 'GPE'),
#  ('hoareareifI', 'ORGANIZATION'),
#  ('aareI', 'ORGANIZATION'),
#  ('totalpolitI', 'ORGANIZATION'),
#  ('syouI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('mexI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('magareinI', 'ORGANIZATION'),
#  ('mexI', 'ORGANIZATION'),
#  ('offI', 'ORGANIZATION'),
#  ('polI', 'ORGANIZATION'),
#  ('delI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('abareahamhI', 'ORGANIZATION'),
#  ('jyoustI', 'ORGANIZATION'),
#  ('pizzaslI', 'ORGANIZATION'),
#  ('pizzaslI', 'ORGANIZATION'),
#  ('delI', 'ORGANIZATION'),
#  ('areI', 'ORGANIZATION'),
#  ('areI', 'ORGANIZATION'),
#  ('areI', 'ORGANIZATION'),
#  ('lipstI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('comyousI', 'ORGANIZATION'),
#  ('analytI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('younifI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('qyouI', 'ORGANIZATION'),
#  ('bareI', 'ORGANIZATION'),
#  ('bjmyouzI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('areepyoublI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('fantastI', 'ORGANIZATION'),
#  ('syouI', 'ORGANIZATION'),
#  ('pareI', 'ORGANIZATION'),
#  ('pI', 'ORGANIZATION'),
#  ('welcomelyoudovI', 'ORGANIZATION'),
#  ('vlI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('notI', 'ORGANIZATION'),
#  ('apeopleI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('pedagrinogrinI', 'ORGANIZATION'),
#  ('typI', 'ORGANIZATION'),
#  ('careI', 'ORGANIZATION'),
#  ('histoareI', 'ORGANIZATION'),
#  ('areadI', 'ORGANIZATION'),
#  ('pareactI', 'ORGANIZATION'),
#  ('optimistI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('semitI', 'ORGANIZATION'),
#  ('choI', 'ORGANIZATION'),
#  ('livelypI', 'ORGANIZATION'),
#  ('afareI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('semitI', 'ORGANIZATION'),
#  ('xenophobI', 'ORGANIZATION'),
#  ('steareeophonI', 'ORGANIZATION'),
#  ('qyouI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('choI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('jyoustI', 'ORGANIZATION'),
#  ('polI', 'ORGANIZATION'),
#  ('comI', 'ORGANIZATION'),
#  ('islamI', 'ORGANIZATION'),
#  ('lipstI', 'ORGANIZATION'),
#  ('caffeineaddI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('areI', 'ORGANIZATION'),
#  ('costaareI', 'ORGANIZATION'),
#  ('jyoustI', 'ORGANIZATION'),
#  ('myoultI', 'ORGANIZATION'),
#  ('magareinI', 'ORGANIZATION'),
#  ('seeanameareI', 'ORGANIZATION'),
#  ('searevI', 'ORGANIZATION'),
#  ('magareinnifI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('islamI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('delI', 'ORGANIZATION'),
#  ('sandwI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('gareinlamtastI', 'ORGANIZATION'),
#  ('syouI', 'ORGANIZATION'),
#  ('anoareexI', 'ORGANIZATION'),
#  ('democareatI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('hoyousemyousI', 'ORGANIZATION'),
#  ('distareI', 'ORGANIZATION'),
#  ('areI', 'ORGANIZATION'),
#  ('tareagareinI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('oaregareinanI', 'ORGANIZATION'),
#  ('dominI', 'ORGANIZATION'),
#  ('optI', 'ORGANIZATION'),
#  ('iandareewmyousI', 'ORGANIZATION'),
#  ('pathetI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('livemyousI', 'ORGANIZATION'),
#  ('careitI', 'ORGANIZATION'),
#  ('careitI', 'ORGANIZATION'),
#  ('careitI', 'ORGANIZATION'),
#  ('searevI', 'ORGANIZATION'),
#  ('advI', 'ORGANIZATION'),
#  ('voI', 'ORGANIZATION'),
#  ('pareoblematI', 'ORGANIZATION'),
#  ('ethnI', 'ORGANIZATION'),
#  ('biblI', 'ORGANIZATION'),
#  ('baarebaareI', 'ORGANIZATION'),
#  ('medI', 'ORGANIZATION'),
#  ('eareadI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('magareinI', 'ORGANIZATION'),
#  ('democareatI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('pareI', 'ORGANIZATION'),
#  ('manyousI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('commyounI', 'ORGANIZATION'),
#  ('searevI', 'ORGANIZATION'),
#  ('ojmadeinameareI', 'ORGANIZATION'),
#  ('tareagareinI', 'ORGANIZATION'),
#  ('areesnI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('seekflI', 'ORGANIZATION'),
#  ('plastI', 'ORGANIZATION'),
#  ('areI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('yoyoustomearesearevI', 'ORGANIZATION'),
#  ('pareoblematI', 'ORGANIZATION'),
#  ('conflI', 'ORGANIZATION'),
#  ('fareiendshI', 'ORGANIZATION'),
#  ('magareinI', 'ORGANIZATION'),
#  ('epI', 'ORGANIZATION'),
#  ('searevI', 'ORGANIZATION'),
#  ('domestI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('twI', 'ORGANIZATION'),
#  ('tI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('manpI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('ameareI', 'GPE'),
#  ('pareI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('clI', 'ORGANIZATION'),
#  ('pathetI', 'ORGANIZATION'),
#  ('avI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('twI', 'ORGANIZATION'),
#  ('areI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('homophobI', 'ORGANIZATION'),
#  ('notifI', 'ORGANIZATION'),
#  ('lyareI', 'ORGANIZATION'),
#  ('areyoustI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('sacareifI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('optimistI', 'ORGANIZATION'),
#  ('devI', 'ORGANIZATION'),
#  ('pyoublI', 'ORGANIZATION'),
#  ('classI', 'ORGANIZATION'),
#  ('tareaffI', 'ORGANIZATION'),
#  ('stI', 'ORGANIZATION'),
#  ('voI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('teareareifI', 'ORGANIZATION'),
#  ('deareareI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('areadI', 'ORGANIZATION'),
#  ('seealislamI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('deareareI', 'ORGANIZATION'),
#  ('afareI', 'ORGANIZATION'),
#  ('classI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('venI', 'ORGANIZATION'),
#  ('venI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('copaameareI', 'ORGANIZATION'),
#  ('voI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('voI', 'ORGANIZATION'),
#  ('hoareareifI', 'ORGANIZATION'),
#  ('islamI', 'ORGANIZATION'),
#  ('analytI', 'ORGANIZATION'),
#  ('sI', 'ORGANIZATION'),
#  ('domestI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('claareI', 'ORGANIZATION'),
#  ('lipstI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('lyareI', 'ORGANIZATION'),
#  ('eareI', 'ORGANIZATION'),
#  ('younethI', 'ORGANIZATION'),
#  ('mexI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('pareayfoareameareI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('voI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('homophobI', 'ORGANIZATION'),
#  ('medI', 'ORGANIZATION'),
#  ('tareyoumpsameareI', 'ORGANIZATION'),
#  ('addI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('areepyoublI', 'ORGANIZATION'),
#  ('pathetI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('abareahamhI', 'ORGANIZATION'),
#  ('ameareI', 'GPE'),
#  ('politI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('dI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('syoupearekI', 'ORGANIZATION'),
#  ('vlI', 'ORGANIZATION'),
#  ('benI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('hispanI', 'ORGANIZATION'),
#  ('complI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('manpI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('vehI', 'ORGANIZATION'),
#  ('complI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('fanepI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('magareinI', 'ORGANIZATION'),
#  ('elliptI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('pyoublI', 'ORGANIZATION'),
#  ('flI', 'ORGANIZATION'),
#  ('mccoaremI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('dI', 'ORGANIZATION'),
#  ('semitI', 'ORGANIZATION'),
#  ('qyouI', 'ORGANIZATION'),
#  ('searevI', 'ORGANIZATION'),
#  ('magareinI', 'ORGANIZATION'),
#  ('jyouI', 'ORGANIZATION'),
#  ('lyoudI', 'ORGANIZATION'),
#  ('ojmadeinameareI', 'ORGANIZATION'),
#  ('areadI', 'ORGANIZATION'),
#  ('areI', 'ORGANIZATION'),
#  ('eareotI', 'ORGANIZATION'),
#  ('distareI', 'ORGANIZATION'),
#  ('fI', 'ORGANIZATION'),
#  ('seeonI', 'ORGANIZATION'),
#  ('dareastI', 'ORGANIZATION'),
#  ('medI', 'ORGANIZATION'),
#  ('pyoublI', 'ORGANIZATION'),
#  ('careitI', 'ORGANIZATION'),
#  ('twI', 'ORGANIZATION'),
#  ('magareinI', 'ORGANIZATION'),
#  ('limpdI', 'ORGANIZATION'),
#  ('ameareI', 'GPE'),
#  ('yoyouarecomI', 'ORGANIZATION'),
#  ('ameareI', 'GPE'),
#  ('ameareI', 'ORGANIZATION'),
#  ('offI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('pareI', 'ORGANIZATION'),
#  ('searevI', 'ORGANIZATION'),
#  ('lipstI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('afareI', 'ORGANIZATION'),
#  ('loveathletI', 'ORGANIZATION'),
#  ('areetareI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('distareI', 'ORGANIZATION'),
#  ('jyoustI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('seekeytoffI', 'ORGANIZATION'),
#  ('sciencefI', 'ORGANIZATION'),
#  ('pastI', 'ORGANIZATION'),
#  ('scenI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('choI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('younI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('searevI', 'ORGANIZATION'),
#  ('evI', 'ORGANIZATION'),
#  ('velI', 'ORGANIZATION'),
#  ('analytI', 'ORGANIZATION'),
#  ('shanatI', 'ORGANIZATION'),
#  ('ayoutomatI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('magareinI', 'ORGANIZATION'),
#  ('knI', 'ORGANIZATION'),
#  ('nI', 'ORGANIZATION'),
#  ('mI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('implI', 'ORGANIZATION'),
#  ('typI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('connectI', 'ORGANIZATION'),
#  ('medI', 'ORGANIZATION'),
#  ('classI', 'ORGANIZATION'),
#  ('offI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('newmyousI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('topI', 'ORGANIZATION'),
#  ('cynI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('economI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('fareiedareI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('typI', 'ORGANIZATION'),
#  ('medI', 'ORGANIZATION'),
#  ('psychologareinI', 'ORGANIZATION'),
#  ('advI', 'ORGANIZATION'),
#  ('delI', 'ORGANIZATION'),
#  ('afareI', 'ORGANIZATION'),
#  ('areadI', 'ORGANIZATION'),
#  ('indI', 'ORGANIZATION'),
#  ('plastI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('pareI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('tareI', 'ORGANIZATION'),
#  ('medI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('islamI', 'ORGANIZATION'),
#  ('polI', 'ORGANIZATION'),
#  ('livelypI', 'ORGANIZATION'),
#  ('careackalogareinI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('voI', 'ORGANIZATION'),
#  ('syouI', 'ORGANIZATION'),
#  ('dogareinmatI', 'ORGANIZATION'),
#  ('choI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('gareinastareI', 'ORGANIZATION'),
#  ('flmedI', 'ORGANIZATION'),
#  ('aneareI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('epI', 'ORGANIZATION'),
#  ('jyounaareI', 'ORGANIZATION'),
#  ('homeoffI', 'ORGANIZATION'),
#  ('pyoublI', 'ORGANIZATION'),
#  ('areI', 'ORGANIZATION'),
#  ('magareinI', 'ORGANIZATION'),
#  ('histoareI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('searevI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('electareI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('mexI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('advI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('searevI', 'ORGANIZATION'),
#  ('hinaholI', 'ORGANIZATION'),
#  ('comI', 'ORGANIZATION'),
#  ('choI', 'ORGANIZATION'),
#  ('dI', 'ORGANIZATION'),
#  ('felI', 'ORGANIZATION'),
#  ('caselI', 'ORGANIZATION'),
#  ('searevI', 'ORGANIZATION'),
#  ('jessI', 'ORGANIZATION'),
#  ('jessI', 'ORGANIZATION'),
#  ('qyoualifI', 'ORGANIZATION'),
#  ('ameareI', 'GPE'),
#  ('ameareI', 'ORGANIZATION'),
#  ('advI', 'ORGANIZATION'),
#  ('slI', 'ORGANIZATION'),
#  ('offI', 'ORGANIZATION'),
#  ('pathetI', 'ORGANIZATION'),
#  ('afareI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('gareinenetI', 'ORGANIZATION'),
#  ('eyougareinenI', 'ORGANIZATION'),
#  ('soyouthafareI', 'ORGANIZATION'),
#  ('clI', 'ORGANIZATION'),
#  ('optimistI', 'ORGANIZATION'),
#  ('areI', 'ORGANIZATION'),
#  ('dI', 'ORGANIZATION'),
#  ('costaareI', 'ORGANIZATION'),
#  ('choI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('physI', 'ORGANIZATION'),
#  ('abareahamhI', 'ORGANIZATION'),
#  ('leI', 'ORGANIZATION'),
#  ('titanI', 'ORGANIZATION'),
#  ('tareopI', 'ORGANIZATION'),
#  ('delI', 'ORGANIZATION'),
#  ('tareI', 'ORGANIZATION'),
#  ('manyousI', 'ORGANIZATION'),
#  ('pathetI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('choI', 'ORGANIZATION'),
#  ('lipstI', 'ORGANIZATION'),
#  ('maccosmetI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('maxI', 'ORGANIZATION'),
#  ('clI', 'ORGANIZATION'),
#  ('tareopI', 'ORGANIZATION'),
#  ('alcoholI', 'ORGANIZATION'),
#  ('careitI', 'ORGANIZATION'),
#  ('areepyoublI', 'ORGANIZATION'),
#  ('gareinonnabeepI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('sandwhI', 'ORGANIZATION'),
#  ('pareI', 'ORGANIZATION'),
#  ('makeameareI', 'ORGANIZATION'),
#  ('areI', 'ORGANIZATION'),
#  ('benefI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('livelypI', 'ORGANIZATION'),
#  ('conflI', 'ORGANIZATION'),
#  ('conflI', 'ORGANIZATION'),
#  ('pareactI', 'ORGANIZATION'),
#  ('fascistI', 'ORGANIZATION'),
#  ('ostareI', 'ORGANIZATION'),
#  ('careapsearevI', 'ORGANIZATION'),
#  ('offI', 'ORGANIZATION'),
#  ('epidemI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('newaddI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('choI', 'ORGANIZATION'),
#  ('nI', 'ORGANIZATION'),
#  ('paI', 'ORGANIZATION'),
#  ('epI', 'ORGANIZATION'),
#  ('allameareI', 'ORGANIZATION'),
#  ('tareopI', 'ORGANIZATION'),
#  ('analytI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('topI', 'ORGANIZATION'),
#  ('athletI', 'ORGANIZATION'),
#  ('dI', 'ORGANIZATION'),
#  ('nI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('economI', 'ORGANIZATION'),
#  ('analytI', 'ORGANIZATION'),
#  ('gareinoogareinleanalytI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('oveareoptimistI', 'ORGANIZATION'),
#  ('areadI', 'ORGANIZATION'),
#  ('vehI', 'ORGANIZATION'),
#  ('physI', 'ORGANIZATION'),
#  ('manyousI', 'ORGANIZATION'),
#  ('pyoutinschoI', 'ORGANIZATION'),
#  ('notI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('advI', 'ORGANIZATION'),
#  ('magareinI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('complI', 'ORGANIZATION'),
#  ('spI', 'ORGANIZATION'),
#  ('spI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('manyousI', 'ORGANIZATION'),
#  ('areI', 'ORGANIZATION'),
#  ('dominI', 'ORGANIZATION'),
#  ('seeanareepyoublI', 'ORGANIZATION'),
#  ('fatboygareinenetI', 'ORGANIZATION'),
#  ('voI', 'ORGANIZATION'),
#  ('typI', 'ORGANIZATION'),
#  ('egareinotistI', 'ORGANIZATION'),
#  ('pathetI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('amI', 'ORGANIZATION'),
#  ('amI', 'ORGANIZATION'),
#  ('voI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('addI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('areepyoublI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('classI', 'ORGANIZATION'),
#  ('calI', 'ORGANIZATION'),
#  ('ecstatI', 'ORGANIZATION'),
#  ('nowI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('toddlearenI', 'ORGANIZATION'),
#  ('areentaloffI', 'ORGANIZATION'),
#  ('qyouI', 'ORGANIZATION'),
#  ('yoyoustomearesearevI', 'ORGANIZATION'),
#  ('notI', 'ORGANIZATION'),
#  ('slI', 'ORGANIZATION'),
#  ('topI', 'ORGANIZATION'),
#  ('teareareifI', 'ORGANIZATION'),
#  ('clI', 'ORGANIZATION'),
#  ('hoareareifI', 'ORGANIZATION'),
#  ('jyoustI', 'ORGANIZATION'),
#  ('polI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('epI', 'ORGANIZATION'),
#  ('entI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('ameareI', 'GPE'),
#  ('fantastI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('fantastI', 'ORGANIZATION'),
#  ('lakelandclassI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('typI', 'ORGANIZATION'),
#  ('slI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('clI', 'ORGANIZATION'),
#  ('ojmadeinameareI', 'ORGANIZATION'),
#  ('tareagareinI', 'ORGANIZATION'),
#  ('areesnI', 'ORGANIZATION'),
#  ('pareejyoudI', 'ORGANIZATION'),
#  ('whiteameareI', 'ORGANIZATION'),
#  ('sI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('spI', 'ORGANIZATION'),
#  ('polI', 'ORGANIZATION'),
#  ('vehI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('pI', 'ORGANIZATION'),
#  ('tareopI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('abareahamhI', 'ORGANIZATION'),
#  ('islamI', 'ORGANIZATION'),
#  ('analytI', 'ORGANIZATION'),
#  ('afareI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('magareinI', 'ORGANIZATION'),
#  ('areI', 'ORGANIZATION'),
#  ('searevI', 'ORGANIZATION'),
#  ('homophobI', 'ORGANIZATION'),
#  ('fitnessaddI', 'GSP'),
#  ('chI', 'ORGANIZATION'),
#  ('areI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('henareI', 'ORGANIZATION'),
#  ('vehI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('makeameareI', 'ORGANIZATION'),
#  ('afareI', 'ORGANIZATION'),
#  ('livelypI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('voI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('notifI', 'ORGANIZATION'),
#  ('mI', 'ORGANIZATION'),
#  ('vindI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('histoareI', 'ORGANIZATION'),
#  ('mI', 'ORGANIZATION'),
#  ('vindI', 'ORGANIZATION'),
#  ('searevI', 'ORGANIZATION'),
#  ('yoyoustomearesearevI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('domestI', 'ORGANIZATION'),
#  ('helI', 'ORGANIZATION'),
#  ('stI', 'ORGANIZATION'),
#  ('tactI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('livelypI', 'ORGANIZATION'),
#  ('leI', 'ORGANIZATION'),
#  ('pI', 'ORGANIZATION'),
#  ('acI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('areadI', 'ORGANIZATION'),
#  ('apathetI', 'ORGANIZATION'),
#  ('vehI', 'ORGANIZATION'),
#  ('classI', 'ORGANIZATION'),
#  ('comI', 'ORGANIZATION'),
#  ('comI', 'ORGANIZATION'),
#  ('searevI', 'ORGANIZATION'),
#  ('homesI', 'ORGANIZATION'),
#  ('syouffI', 'ORGANIZATION'),
#  ('choI', 'ORGANIZATION'),
#  ('pyoutinschoI', 'ORGANIZATION'),
#  ('economI', 'ORGANIZATION'),
#  ('addI', 'ORGANIZATION'),
#  ('bareI', 'ORGANIZATION'),
#  ('iknowI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('tareyoumpsameareI', 'ORGANIZATION'),
#  ('optimistI', 'ORGANIZATION'),
#  ('advI', 'ORGANIZATION'),
#  ('fantastI', 'ORGANIZATION'),
#  ('pI', 'ORGANIZATION'),
#  ('psychedelI', 'ORGANIZATION'),
#  ('clI', 'ORGANIZATION'),
#  ('choI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('areepyoublI', 'ORGANIZATION'),
#  ('teapyoublI', 'ORGANIZATION'),
#  ('notI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('gareinenetI', 'ORGANIZATION'),
#  ('areepyoublI', 'ORGANIZATION'),
#  ('syouI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('areI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('typI', 'ORGANIZATION'),
#  ('medI', 'ORGANIZATION'),
#  ('idiopathI', 'ORGANIZATION'),
#  ('youI', 'ORGANIZATION'),
#  ('vehI', 'ORGANIZATION'),
#  ('voI', 'ORGANIZATION'),
#  ('afareI', 'ORGANIZATION'),
#  ('domestI', 'ORGANIZATION'),
#  ('mexI', 'ORGANIZATION'),
#  ('halodedI', 'ORGANIZATION'),
#  ('tareyoumppareoofameareI', 'ORGANIZATION'),
#  ('infogareinareaphI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('pareI', 'ORGANIZATION'),
#  ('choI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('whiteaddI', 'ORGANIZATION'),
#  ('areI', 'ORGANIZATION'),
#  ('voI', 'ORGANIZATION'),
#  ('areomantI', 'ORGANIZATION'),
#  ('careitI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('afareI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('oaregareinanI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('dareyougareinaddI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('pareactI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('stylistI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('ohopedI', 'ORGANIZATION'),
#  ('botanI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('choI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('jyoustI', 'ORGANIZATION'),
#  ('instapI', 'ORGANIZATION'),
#  ('vehI', 'ORGANIZATION'),
#  ('pI', 'ORGANIZATION'),
#  ('pyoublI', 'ORGANIZATION'),
#  ('folkmyousI', 'ORGANIZATION'),
#  ('offI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('fantastI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('qyouI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('swiftwI', 'ORGANIZATION'),
#  ('vlI', 'ORGANIZATION'),
#  ('jyoustifI', 'ORGANIZATION'),
#  ('basilI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('searevI', 'ORGANIZATION'),
#  ('jyouI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('fantastI', 'ORGANIZATION'),
#  ('epI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('xotI', 'ORGANIZATION'),
#  ('tactI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('areeI', 'ORGANIZATION'),
#  ('hyouskypI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('ameareI', 'GPE'),
#  ('holistI', 'ORGANIZATION'),
#  ('areadI', 'ORGANIZATION'),
#  ('seealislamI', 'ORGANIZATION'),
#  ('voI', 'ORGANIZATION'),
#  ('voI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('syouI', 'ORGANIZATION'),
#  ('syouI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('newmyousI', 'ORGANIZATION'),
#  ('mexI', 'ORGANIZATION'),
#  ('choI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('clI', 'ORGANIZATION'),
#  ('apeopleI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('systemI', 'ORGANIZATION'),
#  ('nI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('topI', 'ORGANIZATION'),
#  ('monI', 'ORGANIZATION'),
#  ('maI', 'ORGANIZATION'),
#  ('doareI', 'ORGANIZATION'),
#  ('yoyoultyouarealenareI', 'ORGANIZATION'),
#  ('effI', 'ORGANIZATION'),
#  ('stI', 'ORGANIZATION'),
#  ('tareaffI', 'ORGANIZATION'),
#  ('offI', 'ORGANIZATION'),
#  ('pathetI', 'ORGANIZATION'),
#  ('injyoustI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('styoupidlogareinI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('complI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('mexI', 'ORGANIZATION'),
#  ('pathetI', 'ORGANIZATION'),
#  ('domestI', 'ORGANIZATION'),
#  ('facevalyouetI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('conflI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('holistI', 'ORGANIZATION'),
#  ('makeameareI', 'ORGANIZATION'),
#  ('myounI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('livemyousI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('lyareI', 'ORGANIZATION'),
#  ('whI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('pyoublI', 'ORGANIZATION'),
#  ('careI', 'ORGANIZATION'),
#  ('ifI', 'ORGANIZATION'),
#  ('caareI', 'ORGANIZATION'),
#  ('pathetI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('ameareI', 'GPE'),
#  ('tareagareinI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('jyouI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('hoareareifI', 'ORGANIZATION'),
#  ('domestI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('choI', 'ORGANIZATION'),
#  ('empathetI', 'ORGANIZATION'),
#  ('ameareI', 'GPE'),
#  ('clI', 'ORGANIZATION'),
#  ('soveareyfyounnypI', 'ORGANIZATION'),
#  ('dareyougareinaddI', 'ORGANIZATION'),
#  ('conflI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('offI', 'ORGANIZATION'),
#  ('medI', 'ORGANIZATION'),
#  ('devI', 'ORGANIZATION'),
#  ('chareonI', 'ORGANIZATION'),
#  ('syouI', 'ORGANIZATION'),
#  ('clI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('twI', 'ORGANIZATION'),
#  ('jodimyousI', 'ORGANIZATION'),
#  ('cosmetI', 'ORGANIZATION'),
#  ('alI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('areepyoublI', 'ORGANIZATION'),
#  ('hysteareI', 'ORGANIZATION'),
#  ('endemI', 'ORGANIZATION'),
#  ('tareagareinI', 'ORGANIZATION'),
#  ('notameareI', 'ORGANIZATION'),
#  ('seeaschoI', 'ORGANIZATION'),
#  ('jyouI', 'ORGANIZATION'),
#  ('pareI', 'ORGANIZATION'),
#  ('teaaddI', 'ORGANIZATION'),
#  ('careitI', 'ORGANIZATION'),
#  ('panI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('offI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('aesthetI', 'ORGANIZATION'),
#  ('vI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('bareI', 'ORGANIZATION'),
#  ('hemadeameareI', 'ORGANIZATION'),
#  ('botanI', 'ORGANIZATION'),
#  ('hispanI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('flI', 'ORGANIZATION'),
#  ('areepyoublI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('delI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('hoonI', 'ORGANIZATION'),
#  ('instapI', 'ORGANIZATION'),
#  ('pareactI', 'ORGANIZATION'),
#  ('convI', 'ORGANIZATION'),
#  ('jyoustI', 'ORGANIZATION'),
#  ('saarecastI', 'ORGANIZATION'),
#  ('pyoublI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('areepyoublI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('jamaI', 'ORGANIZATION'),
#  ('epI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('areI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('magareinI', 'ORGANIZATION'),
#  ('magareinI', 'ORGANIZATION'),
#  ('pI', 'ORGANIZATION'),
#  ('careitI', 'ORGANIZATION'),
#  ('pedantI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('ameareI', 'GPE'),
#  ('whI', 'ORGANIZATION'),
#  ('analytI', 'ORGANIZATION'),
#  ('pareI', 'ORGANIZATION'),
#  ('letI', 'ORGANIZATION'),
#  ('letI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('domestI', 'ORGANIZATION'),
#  ('dedI', 'ORGANIZATION'),
#  ('nI', 'ORGANIZATION'),
#  ('alI', 'ORGANIZATION'),
#  ('ebonI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('blackmaveareI', 'ORGANIZATION'),
#  ('logareinI', 'ORGANIZATION'),
#  ('optimistI', 'ORGANIZATION'),
#  ('arehetoareI', 'ORGANIZATION'),
#  ('searevI', 'ORGANIZATION'),
#  ('myousI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('zoologareinI', 'ORGANIZATION'),
#  ('exotI', 'ORGANIZATION'),
#  ('novI', 'ORGANIZATION'),
#  ('pareactI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('jyoustI', 'ORGANIZATION'),
#  ('choI', 'ORGANIZATION'),
#  ('notifI', 'ORGANIZATION'),
#  ('oaregareinanI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('pareactI', 'ORGANIZATION'),
#  ('pareactI', 'ORGANIZATION'),
#  ('ecstatI', 'ORGANIZATION'),
#  ('containingareinfareiedareI', 'ORGANIZATION'),
#  ('chI', 'ORGANIZATION'),
#  ('saarecastI', 'ORGANIZATION'),
#  ('ejyouI', 'ORGANIZATION'),
#  ('ameareI', 'ORGANIZATION'),
#  ('politI', 'ORGANIZATION'),
#  ('iareonI', 'ORGANIZATION'),
#  ('mystI', 'ORGANIZATION'),
#  ('psychI', 'ORGANIZATION'),
#  ('islamI', 'ORGANIZATION'),
#  ('jyouI', 'ORGANIZATION'),
#  ...]

# %%
# TOP-20 популярных NER
collections.Counter(tokens_list).most_common(20)
# Out:
# [(('myousI', 'ORGANIZATION'), 118),
#  (('ameareI', 'ORGANIZATION'), 95),
#  (('politI', 'ORGANIZATION'), 51),
#  (('vI', 'ORGANIZATION'), 38),
#  (('chI', 'ORGANIZATION'), 35),
#  (('whI', 'ORGANIZATION'), 26),
#  (('searevI', 'ORGANIZATION'), 24),
#  (('choI', 'ORGANIZATION'), 22),
#  (('areI', 'ORGANIZATION'), 20),
#  (('pareI', 'ORGANIZATION'), 18),
#  (('voI', 'ORGANIZATION'), 17),
#  (('magareinI', 'ORGANIZATION'), 17),
#  (('afareI', 'ORGANIZATION'), 16),
#  (('areepyoublI', 'ORGANIZATION'), 14),
#  (('pathetI', 'ORGANIZATION'), 13),
#  (('pyoublI', 'ORGANIZATION'), 12),
#  (('clI', 'ORGANIZATION'), 12),
#  (('ameareI', 'GPE'), 11),
#  (('careitI', 'ORGANIZATION'), 11),
#  (('analytI', 'ORGANIZATION'), 10)]

# %%
# TOP-20 популярных личностей
person_tokens_list = [(ent[0], ent[1]) for ent in tokens_list if ent[1] == 'PERSON']
collections.Counter(person_tokens_list).most_common(20)
# Out:
# []

# %%
# TOP-20 популярных организаций
org_tokens_list = [(ent[0], ent[1]) for ent in tokens_list if ent[1] == 'ORGANIZATION']
collections.Counter(org_tokens_list).most_common(20)
# Out:
# [(('myousI', 'ORGANIZATION'), 118),
#  (('ameareI', 'ORGANIZATION'), 95),
#  (('politI', 'ORGANIZATION'), 51),
#  (('vI', 'ORGANIZATION'), 38),
#  (('chI', 'ORGANIZATION'), 35),
#  (('whI', 'ORGANIZATION'), 26),
#  (('searevI', 'ORGANIZATION'), 24),
#  (('choI', 'ORGANIZATION'), 22),
#  (('areI', 'ORGANIZATION'), 20),
#  (('pareI', 'ORGANIZATION'), 18),
#  (('voI', 'ORGANIZATION'), 17),
#  (('magareinI', 'ORGANIZATION'), 17),
#  (('afareI', 'ORGANIZATION'), 16),
#  (('areepyoublI', 'ORGANIZATION'), 14),
#  (('pathetI', 'ORGANIZATION'), 13),
#  (('pyoublI', 'ORGANIZATION'), 12),
#  (('clI', 'ORGANIZATION'), 12),
#  (('careitI', 'ORGANIZATION'), 11),
#  (('analytI', 'ORGANIZATION'), 10),
#  (('fantastI', 'ORGANIZATION'), 10)]

# %%
# сколько уникальных NER найдено с помощью spacy?
len(collections.Counter(tokens_list))
# Out:
# 369

# %% [markdown]
# ### Задание 3.
# Какая из библиотек по вашему лучше отработала? Сравните качество полученных most_common NER и количество распознаных NER.

# %% [markdown]
# в Nltk очень много шума из-за заглавных букв, качественнее результат дала библиотека Spacy.
