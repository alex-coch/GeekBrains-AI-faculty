# %% [markdown]
# ## Практическое задание
#
#
#     1. Попробуйте изменить параметры нейронной сети работающей с датасетом imdb либо нейронной сети работающей c airline-passengers(она прилагается вместе с датасетом к уроку в виде отдельного скрипта) так, чтобы улучшить ее точность. Приложите анализ.
#     2. Попробуйте изменить параметры нейронной сети генерирующий текст таким образом, чтобы добиться генерации как можно более осмысленного текста. Пришлите лучший получившейся у вас текст и опишите, что вы предприняли, чтобы его получить. Можно использовать текст другого прозведения.
#     3.* Попробуйте на numpy реализовать нейронную сеть архитектуры LSTM
#     4.* Предложите свои варианты решения проблемы исчезающего градиента в RNN

# %%
from __future__ import print_function

from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM
from keras.datasets import imdb
from keras.utils import pad_sequences

max_features = 20000
# обрезание текстов после данного количества слов (среди top max_features наиболее используемые слова)
maxlen = 80
batch_size = 65 # размер батча увеличен

# %%
print('Загрузка данных...')
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
print(len(x_train), 'тренировочные последовательности')
print(len(x_test), 'тестовые последовательности')

print('Pad последовательности (примеров в x единицу времени)')
x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)

print('Построение модели...')
model = Sequential()
model.add(Embedding(max_features, 135))
model.add(LSTM(135, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Загрузка данных...
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step
# 25000 тренировочные последовательности
# 25000 тестовые последовательности
# Pad последовательности (примеров в x единицу времени)
# x_train shape: (25000, 80)
# x_test shape: (25000, 80)
# Построение модели...
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 135)         2700000
#
#  lstm (LSTM)                 (None, 135)               146340
#
#  dense (Dense)               (None, 1)                 136
#
# =================================================================
# Total params: 2,846,476
# Trainable params: 2,846,476
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers import Adam,Adamax,RMSprop, Adagrad

# %%
# стоит попробовать использовать другие оптимайзер и другие конфигурации оптимайзеров 
model.compile(loss='binary_crossentropy',
              optimizer=Adagrad(learning_rate=0.01), #выбор оптимизатора Adagrad с ручной настройкой скорости обучения
              metrics=['accuracy'])

print('Процесс обучения...')
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=1,
          validation_data=(x_test, y_test))
score, acc = model.evaluate(x_test, y_test,
                            batch_size=batch_size)
print('Результат при тестировании:', score)
print('Тестовая точность:', acc)

# Результат при тестировании: 0.3440701961517334
# Тестовая точность: 0.8518000245094299
# Out:
# Процесс обучения...
# 385/385 [==============================] - 139s 347ms/step - loss: 0.6927 - accuracy: 0.5154 - val_loss: 0.6925 - val_accuracy: 0.5207
# 385/385 [==============================] - 10s 25ms/step - loss: 0.6925 - accuracy: 0.5207
# Результат при тестировании: 0.6924753785133362
# Тестовая точность: 0.5207200050354004

# %% [markdown]
# *В целом наиболее значимое улучшение вызвал выбор оптимизатора Adagrad. Увеличение количество слоев сети либо эпох не вызывает учучшения*

# %%
import numpy as np
from keras.layers import Dense, Activation
from tensorflow.keras.layers import LSTM, SimpleRNN, GRU
from keras.models import Sequential

# %%
with open("alice_in_wonderland.txt", 'rb') as _in:
    lines = []
    for line in _in:
        line = line.strip().lower().decode("utf-8", "ignore")
        if len(line) == 0:
            continue
        lines.append(line)
text = " ".join(lines)
chars = set([c for c in text])
nb_chars = len(chars)

# %%
# создание индекса символов и reverse mapping чтобы передвигаться между значениями numerical
# ID и определенный символом. Numerical ID будет соответсвовать колонке
# число при использовании one-hot кодировки для представления входов символов
char2index = {c: i for i, c in enumerate(chars)}
index2char = {i: c for i, c in enumerate(chars)}

# для удобства выбирается фиксированную длина последовательности 10 символов 
SEQLEN, STEP = 10, 1
input_chars, label_chars = [], []

# конвертация data в серии разных SEQLEN-length субпоследовательностей
for i in range(0, len(text) - SEQLEN, STEP):
    input_chars.append(text[i: i + SEQLEN])
    label_chars.append(text[i + SEQLEN])


# Вычисление one-hot encoding входных последовательностей X и следующего символа (the label) y

X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=bool)
y = np.zeros((len(input_chars), nb_chars), dtype=bool)
for i, input_char in enumerate(input_chars):
    for j, ch in enumerate(input_char):
        X[i, j, char2index[ch]] = 1
    y[i, char2index[label_chars[i]]] = 1


# установка ряда метапамертров  для нейронной сети и процесса тренировки
BATCH_SIZE, HIDDEN_SIZE = 128, 128
NUM_ITERATIONS = 25
NUM_EPOCHS_PER_ITERATION = 10
NUM_PREDS_PER_EPOCH = 100

# %%
model = Sequential()
model.add(
    GRU(  # вы можете изменить эту часть на LSTM или SimpleRNN, чтобы попробовать альтернативы
        HIDDEN_SIZE,
        return_sequences=False,
        input_shape=(SEQLEN, nb_chars),
        unroll=True
    )
)
model.add(Dense(nb_chars))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer=RMSprop())


# выполнение серий тренировочных и демонстрационных итераций 
for iteration in range(NUM_ITERATIONS):

    # для каждой итерации запуск передачи данных в модель 
    print("=" * 50)
    print("Итерация #: %d" % (iteration))
    model.fit(X, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)

    # Select a random example input sequence.
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]

    # для числа шагов предсказаний использование текущей тренируемой модели 
    # конструирование one-hot encoding для тестирования input и добавление предсказания.
    print("Генерация из посева: %s" % (test_chars))
    print(test_chars, end="")
    for i in range(NUM_PREDS_PER_EPOCH):

        # здесь one-hot encoding.
        X_test = np.zeros((1, SEQLEN, nb_chars))
        for j, ch in enumerate(test_chars):
            X_test[0, j, char2index[ch]] = 1

        # осуществление предсказания с помощью текущей модели.
        pred = model.predict(X_test, verbose=0)[0]
        y_pred = index2char[np.argmax(pred)]

        # вывод предсказания добавленного к тестовому примеру 
        print(y_pred, end="")

        # инкрементация тестового примера содержащего предсказание
        test_chars = test_chars[1:] + y_pred
print()
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# ==================================================
# Итерация #: 0
# Epoch 1/10
# 1265/1265 [==============================] - 11s 7ms/step - loss: 2.3570
# Epoch 2/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 1.9272
# Epoch 3/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 1.7603
# Epoch 4/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 1.6492
# Epoch 5/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 1.5680
# Epoch 6/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 1.5053
# Epoch 7/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 1.4532
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 1.4096
# Epoch 9/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 1.3721
# Epoch 10/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 1.3393
# Генерация из посева: ime). ‘don
# ime). ‘don’t be a great the tried to herself, ‘i should the dormouse which was a little thing was and all the ==================================================
# Итерация #: 1
# Epoch 1/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 1.3109
# Epoch 2/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 1.2844
# Epoch 3/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 1.2612
# Epoch 4/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 1.2407
# Epoch 5/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 1.2209
# Epoch 6/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 1.2024
# Epoch 7/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 1.1856
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 1.1699
# Epoch 9/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 1.1543
# Epoch 10/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 1.1404
# Генерация из посева: of the mus
# of the mustron so more to alice and her head some of the words of the words of the words of the words of the w==================================================
# Итерация #: 2
# Epoch 1/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 1.1274
# Epoch 2/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 1.1145
# Epoch 3/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 1.1020
# Epoch 4/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 1.0903
# Epoch 5/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 1.0794
# Epoch 6/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 1.0692
# Epoch 7/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 1.0578
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 1.0491
# Epoch 9/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 1.0396
# Epoch 10/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 1.0305
# Генерация из посева:  nose-- wh
#  nose-- why doesn’t matter which was so much as she could not think of the tried to herself, ‘it was and did n==================================================
# Итерация #: 3
# Epoch 1/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 1.0222
# Epoch 2/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 1.0142
# Epoch 3/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 1.0068
# Epoch 4/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.9988
# Epoch 5/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.9916
# Epoch 6/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.9865
# Epoch 7/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.9778
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.9721
# Epoch 9/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.9672
# Epoch 10/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.9602
# Генерация из посева: of a proje
# of a project gutenberg-tm electronic works in a great hurry. ‘i wish i shall thought to herself, and all remar==================================================
# Итерация #: 4
# Epoch 1/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.9555
# Epoch 2/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.9503
# Epoch 3/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.9439
# Epoch 4/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.9395
# Epoch 5/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.9341
# Epoch 6/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.9298
# Epoch 7/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.9253
# Epoch 8/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.9203
# Epoch 9/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.9177
# Epoch 10/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.9119
# Генерация из посева:  it so ver
#  it so very teem, the knave of hearts, and the mouse to the gryphon went on was in a low triedd a little becau==================================================
# Итерация #: 5
# Epoch 1/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.9085
# Epoch 2/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.9063
# Epoch 3/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.9029
# Epoch 4/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8982
# Epoch 5/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8946
# Epoch 6/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.8915
# Epoch 7/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8890
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8851
# Epoch 9/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.8832
# Epoch 10/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8800
# Генерация из посева:  fur and w
#  fur and who had felt quite strange at first, and then sat down its head down, and had been found it as she sp==================================================
# Итерация #: 6
# Epoch 1/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.8778
# Epoch 2/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8747
# Epoch 3/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8729
# Epoch 4/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.8710
# Epoch 5/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8665
# Epoch 6/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8643
# Epoch 7/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.8627
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8608
# Epoch 9/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8586
# Epoch 10/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8548
# Генерация из посева: ph 1.e bel
# ph 1.e belig.’ ‘not the full project gutenberg literary archive foundation, the wood for this can do with this==================================================
# Итерация #: 7
# Epoch 1/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8538
# Epoch 2/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.8525
# Epoch 3/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8506
# Epoch 4/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8475
# Epoch 5/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.8457
# Epoch 6/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.8446
# Epoch 7/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8422
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8410
# Epoch 9/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.8385
# Epoch 10/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8377
# Генерация из посева: or that le
# or that led a time his shrong but on happered,’ said the cat, and made an anven an from his execations mersiby==================================================
# Итерация #: 8
# Epoch 1/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8365
# Epoch 2/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8341
# Epoch 3/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.8335
# Epoch 4/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8319
# Epoch 5/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8309
# Epoch 6/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8275
# Epoch 7/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.8265
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8250
# Epoch 9/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8248
# Epoch 10/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.8239
# Генерация из посева: ce and a l
# ce and a long habfing one in it are of the soupity, and this work or creat at distributing or liet a little wh==================================================
# Итерация #: 9
# Epoch 1/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.8225
# Epoch 2/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.8207
# Epoch 3/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8194
# Epoch 4/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8188
# Epoch 5/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.8177
# Epoch 6/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8165
# Epoch 7/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8142
# Epoch 8/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.8139
# Epoch 9/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8114
# Epoch 10/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8118
# Генерация из посева:  as it lef
#  as it left no mark on the ground as she had not gone held her head in the others took the hookah out of its m==================================================
# Итерация #: 10
# Epoch 1/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8116
# Epoch 2/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8095
# Epoch 3/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.8085
# Epoch 4/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8081
# Epoch 5/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8072
# Epoch 6/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.8057
# Epoch 7/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8044
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8040
# Epoch 9/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.8029
# Epoch 10/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8011
# Генерация из посева: down that
# down that parsaying it all in her life. indait, that it was all the time they were all that she was now and th==================================================
# Итерация #: 11
# Epoch 1/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.8009
# Epoch 2/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.8005
# Epoch 3/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7996
# Epoch 4/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.8009
# Epoch 5/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7972
# Epoch 6/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7967
# Epoch 7/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.7958
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7958
# Epoch 9/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7935
# Epoch 10/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7946
# Генерация из посева: ypertext f
# ypertext for a minute or two, they were all that she was things as stive to get to the door, they repeated the==================================================
# Итерация #: 12
# Epoch 1/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7943
# Epoch 2/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.7921
# Epoch 3/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7911
# Epoch 4/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7907
# Epoch 5/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.7897
# Epoch 6/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.7903
# Epoch 7/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7880
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7863
# Epoch 9/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.7867
# Epoch 10/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7883
# Генерация из посева: er feel ve
# er feel very sleep these that it was a partare, then the distance, and was going to liven lowing of the time t==================================================
# Итерация #: 13
# Epoch 1/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7857
# Epoch 2/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7854
# Epoch 3/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7839
# Epoch 4/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.7841
# Epoch 5/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7846
# Epoch 6/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7829
# Epoch 7/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.7811
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7817
# Epoch 9/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7806
# Epoch 10/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.7815
# Генерация из посева:  a minute
#  a minute or two, it was a project gutenberg-tm electronic works if you do not agree to and acceibg to deness ==================================================
# Итерация #: 14
# Epoch 1/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7783
# Epoch 2/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.7788
# Epoch 3/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7779
# Epoch 4/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7787
# Epoch 5/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.7753
# Epoch 6/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7777
# Epoch 7/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7763
# Epoch 8/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.7757
# Epoch 9/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7773
# Epoch 10/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7733
# Генерация из посева: hat the fl
# hat the flame of a cansuery, she was sorement who trembing i support. project gutenberg-tm works cames to and ==================================================
# Итерация #: 15
# Epoch 1/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7735
# Epoch 2/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7735
# Epoch 3/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.7737
# Epoch 4/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7736
# Epoch 5/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7711
# Epoch 6/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.7726
# Epoch 7/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7721
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7709
# Epoch 9/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7711
# Epoch 10/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.7697
# Генерация из посева:  specified
#  specified in stack and miserawleillon, ‘no crietly white might an inchessing the poor little thing as “i main==================================================
# Итерация #: 16
# Epoch 1/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.7697
# Epoch 2/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7695
# Epoch 3/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7680
# Epoch 4/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7682
# Epoch 5/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.7695
# Epoch 6/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7676
# Epoch 7/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7691
# Epoch 8/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.7662
# Epoch 9/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7677
# Epoch 10/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7676
# Генерация из посева: fell aslee
# fell asleep in her lises ad in an whe herself very snedidy fold about in all the way of expecting alice was no==================================================
# Итерация #: 17
# Epoch 1/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7657
# Epoch 2/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7665
# Epoch 3/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.7644
# Epoch 4/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7651
# Epoch 5/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7637
# Epoch 6/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.7644
# Epoch 7/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7647
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7632
# Epoch 9/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.7620
# Epoch 10/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7628
# Генерация из посева: gutenberg”
# gutenberg” is take a court of mind complifiemany.’ so said nothing else tread curleed--and so its made you soo==================================================
# Итерация #: 18
# Epoch 1/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.7611
# Epoch 2/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7612
# Epoch 3/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7630
# Epoch 4/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.7598
# Epoch 5/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7622
# Epoch 6/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7617
# Epoch 7/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7599
# Epoch 8/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.7592
# Epoch 9/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7608
# Epoch 10/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7601
# Генерация из посева: fication,”
# fication,”’ alice said nothing. ‘no rose work the time they were glad to the chilfuar little chin if i beg now==================================================
# Итерация #: 19
# Epoch 1/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7593
# Epoch 2/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7584
# Epoch 3/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.7589
# Epoch 4/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7589
# Epoch 5/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7578
# Epoch 6/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7583
# Epoch 7/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7584
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7581
# Epoch 9/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7571
# Epoch 10/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.7566
# Генерация из посева: etely. ver
# etely. very going out alice as some things and houged, and began stat!’ cruss and all the peoccuped ove reneeb==================================================
# Итерация #: 20
# Epoch 1/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7558
# Epoch 2/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.7575
# Epoch 3/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7551
# Epoch 4/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7566
# Epoch 5/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7566
# Epoch 6/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7556
# Epoch 7/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7549
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7549
# Epoch 9/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.7563
# Epoch 10/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7555
# Генерация из посева: ld go with
# ld go with yed,’ chap entur-legan yout a large much mustle texcupine that she was to get high: ‘i’ve something==================================================
# Итерация #: 21
# Epoch 1/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.7546
# Epoch 2/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7537
# Epoch 3/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7552
# Epoch 4/10
# 1265/1265 [==============================] - 8s 6ms/step - loss: 0.7542
# Epoch 5/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7527
# Epoch 6/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7537
# Epoch 7/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7522
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7538
# Epoch 9/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7525
# Epoch 10/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7527
# Генерация из посева: essor mich
# essor michate remarked. ‘there’s a by,’ said the caterpillar the lobsters, and the queen had it houghor took t==================================================
# Итерация #: 22
# Epoch 1/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7522
# Epoch 2/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7523
# Epoch 3/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7526
# Epoch 4/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7531
# Epoch 5/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7510
# Epoch 6/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.7513
# Epoch 7/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7508
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7514
# Epoch 9/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7502
# Epoch 10/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7502
# Генерация из посева: l.’ ‘in th
# l.’ ‘in that the seaves without for her surprise.’ ‘it’s a puncomioning about in all direchiog. then the conve==================================================
# Итерация #: 23
# Epoch 1/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7491
# Epoch 2/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7508
# Epoch 3/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7500
# Epoch 4/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.7500
# Epoch 5/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7499
# Epoch 6/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7506
# Epoch 7/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.7484
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7496
# Epoch 9/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7498
# Epoch 10/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.7475
# Генерация из посева:  the fifth
#  the fifth nothing in a very hurtre. ‘perhaps it i cat’sed the door ons of the trees behind howselly as stirn ==================================================
# Итерация #: 24
# Epoch 1/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7486
# Epoch 2/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.7482
# Epoch 3/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7481
# Epoch 4/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7480
# Epoch 5/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.7472
# Epoch 6/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7491
# Epoch 7/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7487
# Epoch 8/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7472
# Epoch 9/10
# 1265/1265 [==============================] - 8s 7ms/step - loss: 0.7472
# Epoch 10/10
# 1265/1265 [==============================] - 9s 7ms/step - loss: 0.7479
# Генерация из посева: to the que
# to the queen said severely as the see, of the lobster quadrille to leave off that did cat executioner my foot

# %% [markdown]
# Увеличение количества эпох и итераций приводит к генерации более осмысленного текста
# to alice was said the groject gutenter the cousted - лучший пример

# %% [markdown]
# - Одним из вариантов решения проблемы исчезающего градиента является применение остаточный сетей (ResNets) - они создают ансамбль из множество мелких сетей. Остаточные нейронные сети достигают решения проблемы исчезающего градиента с помощью коротких путей или “пропущенных соединений” для перемещения по различным слоям. Пропуск слоев освобождает сеть от осложнений, упрощая ее, используя очень мало слоев на начальном этапе обучения. Это ускоряет обучение в десять раз, минимизируя эффект исчезновения градиентов.
#
#
# - Можно использовать другие способы оптимизации, не использующие градиент (например генетический алгоритм)

# %% [markdown]
# Варианты решения проблемы исчезающего градиента в RNN:
#
# 1. Использование архитектур наподобие LSTM;
# 2. Инициализировать веса так, чтобы минимизировать вероятность затухания градиентов;
# 3. Использовать функцию активации leaky relu или swish;
# 4. Добавление градиентного шума.
